# %% [markdown]
# # Configure Aggregate Module Params
#
# This notebook should be used as a test for ensuring correct aggregate parameters before aggregate processing.
# Cells marked with <font color='red'>SET PARAMETERS</font> contain crucial variables that need to be set according to your specific experimental setup and data organization.
# Please review and modify these variables as needed before proceeding with the analysis.

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Fixed parameters for aggregate module
#
# - `CONFIG_FILE_PATH`: Path to a Brieflow config file used during processing. Absolute or relative to where workflows are run from.

# %%
CONFIG_FILE_PATH = "config/config.yml"

# %%
from pathlib import Path
from itertools import product
import random

import yaml
import pandas as pd
import matplotlib.pyplot as plt

from lib.shared.file_utils import get_filename, load_parquet_subset
from lib.aggregate.cell_data_utils import split_cell_data, channel_combo_subset
from lib.aggregate.cell_classification import CellClassifier
from lib.aggregate.montage_utils import create_cell_montage, add_filenames
from lib.aggregate.filter import (
    query_filter,
    perturbation_filter,
    missing_values_filter,
    intensity_filter,
)
from lib.aggregate.align import (
    prepare_alignment_data,
    pca_variance_plot,
    embed_by_pca,
    tvn_on_controls,
)
from lib.aggregate.aggregate import aggregate
from lib.aggregate.eval_aggregate import (
    nas_summary,
    summarize_cell_data,
    plot_feature_distributions,
)
from lib.shared.configuration_utils import CONFIG_FILE_HEADER

random.seed(42)

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Testing on subset of data
#
# - `TEST_PLATE`: Plate used for testing configuration
# - `TEST_WELL_1`: First well identifier used for testing configuration
# - `TEST_WELL_2`: Second well identifier used for testing configuration

# %%
TEST_PLATE = 1
TEST_WELL_1 = "A1"
TEST_WELL_2 = "A2"

# %%
# load config file and determine root path
with open(CONFIG_FILE_PATH, "r") as config_file:
    config = yaml.safe_load(config_file)
ROOT_FP = Path(config["all"]["root_fp"])

# Load subset of data
# Takes ~1 minute
merge_final_fp = (
    ROOT_FP
    / "merge"
    / "parquets"
    / get_filename({"plate": TEST_PLATE, "well": TEST_WELL_1}, "merge_final", "parquet")
)
cell_data = load_parquet_subset(merge_final_fp, n_rows=25000)

merge_final_fp_2 = (
    ROOT_FP
    / "merge"
    / "parquets"
    / get_filename({"plate": TEST_PLATE, "well": TEST_WELL_2}, "merge_final", "parquet")
)
cell_data_2 = load_parquet_subset(merge_final_fp_2, n_rows=25000)

cell_data = pd.concat([cell_data, cell_data_2], ignore_index=True)
cell_data
# Out:
# Reading first 25,000 rows from brieflow_output/merge/parquets/P-1_W-A1__merge_final.parquet
# Reading first 25,000 rows from brieflow_output/merge/parquets/P-1_W-A2__merge_final.parquet
#        plate well  tile  cell_0          i_0          j_0  site  cell_1  \
# 0          1   A1   514     841  1479.657100  1480.528701   140    2684
# 1          1   A1   129     410  1480.853636  1479.342273    36    2128
# 2          1   A1  1300     524  1478.354236  1478.312542   352    1033
# 3          1   A1  1249     432  1482.248657  1479.001466   325    2576
# 4          1   A1  1086     590  1483.420965  1477.997504   303    1467
# ...      ...  ...   ...     ...          ...          ...   ...     ...
# 49995      1   A2   441     484  1623.648581  1686.254591   136    1098
# 49996      1   A2   512     580  1597.578726  1702.158153   139    3593
# 49997      1   A2    29     304  1228.653559  1477.918865     9    1888
# 49998      1   A2   428     455  1244.867795  1568.860391   102    2514
# 49999      1   A2   621     313  1228.765971  1471.665402   171     637
#
#                i_1          j_1  ...  cytoplasm_zernike_9_1  \
# 0       482.533333   439.355556  ...               0.096474
# 1      1032.202381   482.273810  ...               0.032118
# 2       362.226804   361.036082  ...               0.047223
# 3       990.076023   998.456140  ...               0.027419
# 4       456.075630  1016.319328  ...               0.065412
# ...            ...          ...  ...                    ...
# 49995   488.268041   499.556701  ...               0.017427
# 49996  1136.683761   501.683761  ...               0.096492
# 49997   969.857955   496.948864  ...               0.030530
# 49998  1034.255556   474.433333  ...               0.075163
# 49999   330.919463  1062.765101  ...               0.069208
#
#        cytoplasm_zernike_9_3  cytoplasm_zernike_9_5 cytoplasm_zernike_9_7  \
# 0                   0.075336               0.041893              0.063991
# 1                   0.051637               0.080861              0.062261
# 2                   0.058451               0.025184              0.015263
# 3                   0.049565               0.002138              0.050710
# 4                   0.026204               0.076101              0.016644
# ...                      ...                    ...                   ...
# 49995               0.080226               0.024950              0.041787
# 49996               0.016776               0.029052              0.006651
# 49997               0.049919               0.021309              0.009734
# 49998               0.026355               0.133785              0.106438
# 49999               0.045427               0.074232              0.025283
#
#       cytoplasm_zernike_9_9 cytoplasm_number_neighbors_1  \
# 0                  0.023977                            3
# 1                  0.019221                            6
# 2                  0.011378                            5
# 3                  0.030450                            5
# 4                  0.021584                            4
# ...                     ...                          ...
# 49995              0.009289                            4
# 49996              0.031137                            6
# 49997              0.021220                            5
# 49998              0.080470                            5
# 49999              0.006416                            4
#
#       cytoplasm_percent_touching_1 cytoplasm_first_neighbor_distance  \
# 0                         0.400000                         52.315316
# 1                         0.580460                         67.654669
# 2                         0.533742                         69.517492
# 3                         0.601732                         65.975278
# 4                         0.597077                         69.132273
# ...                            ...                               ...
# 49995                     0.553640                         70.180811
# 49996                     0.667939                         80.207366
# 49997                     0.468798                         83.887045
# 49998                     0.524150                         59.698493
# 49999                     0.632653                         74.117513
#
#       cytoplasm_second_neighbor_distance cytoplasm_angle_between_neighbors
# 0                              61.488805                        123.993893
# 1                              85.746446                        154.688886
# 2                              79.197079                        136.690890
# 3                              66.433083                        176.821726
# 4                              73.365904                        139.537211
# ...                                  ...                               ...
# 49995                          70.523472                         65.284275
# 49996                          81.476249                        154.646724
# 49997                          90.403964                        167.108292
# 49998                          61.090044                         76.440311
# 49999                          76.267903                        138.685250
#
# [50000 rows x 4161 columns]

# %%
for col in cell_data.columns:
    print(col)
# Out:
# plate
# well
# tile
# cell_0
# i_0
# j_0
# site
# cell_1
# i_1
# j_1
# distance
# fov_distance_0
# fov_distance_1
# cell_barcode_0
# gene_symbol_0
# no_recomb_0
# cell_barcode_1
# gene_symbol_1
# no_recomb_1
# mapped_single_gene
# channels_min
# nucleus_i
# nucleus_j
# nucleus_bounds_0
# nucleus_bounds_1
# nucleus_bounds_2
# nucleus_bounds_3
# cell_i
# cell_j
# cell_bounds_0
# cell_bounds_1
# cell_bounds_2
# cell_bounds_3
# cytoplasm_i
# cytoplasm_j
# cytoplasm_bounds_0
# cytoplasm_bounds_1
# cytoplasm_bounds_2
# cytoplasm_bounds_3
# nucleus_DAPI_int
# nucleus_Ki-67_int
# nucleus_COXIV_int
# nucleus_Caspase-3_int
# nucleus_WGA_int
# nucleus_aTubulin_int
# nucleus_Vimentin_int
# nucleus_gH2AX_int
# nucleus_Phalloidin_int
# nucleus_DAPI_mean
# nucleus_Ki-67_mean
# nucleus_COXIV_mean
# nucleus_Caspase-3_mean
# nucleus_WGA_mean
# nucleus_aTubulin_mean
# nucleus_Vimentin_mean
# nucleus_gH2AX_mean
# nucleus_Phalloidin_mean
# nucleus_DAPI_std
# nucleus_Ki-67_std
# nucleus_COXIV_std
# nucleus_Caspase-3_std
# nucleus_WGA_std
# nucleus_aTubulin_std
# nucleus_Vimentin_std
# nucleus_gH2AX_std
# nucleus_Phalloidin_std
# nucleus_DAPI_max
# nucleus_Ki-67_max
# nucleus_COXIV_max
# nucleus_Caspase-3_max
# nucleus_WGA_max
# nucleus_aTubulin_max
# nucleus_Vimentin_max
# nucleus_gH2AX_max
# nucleus_Phalloidin_max
# nucleus_DAPI_min
# nucleus_Ki-67_min
# nucleus_COXIV_min
# nucleus_Caspase-3_min
# nucleus_WGA_min
# nucleus_aTubulin_min
# nucleus_Vimentin_min
# nucleus_gH2AX_min
# nucleus_Phalloidin_min
# nucleus_DAPI_int_edge
# nucleus_Ki-67_int_edge
# nucleus_COXIV_int_edge
# nucleus_Caspase-3_int_edge
# nucleus_WGA_int_edge
# nucleus_aTubulin_int_edge
# nucleus_Vimentin_int_edge
# nucleus_gH2AX_int_edge
# nucleus_Phalloidin_int_edge
# nucleus_DAPI_mean_edge
# nucleus_Ki-67_mean_edge
# nucleus_COXIV_mean_edge
# nucleus_Caspase-3_mean_edge
# nucleus_WGA_mean_edge
# nucleus_aTubulin_mean_edge
# nucleus_Vimentin_mean_edge
# nucleus_gH2AX_mean_edge
# nucleus_Phalloidin_mean_edge
# nucleus_DAPI_std_edge
# nucleus_Ki-67_std_edge
# nucleus_COXIV_std_edge
# nucleus_Caspase-3_std_edge
# nucleus_WGA_std_edge
# nucleus_aTubulin_std_edge
# nucleus_Vimentin_std_edge
# nucleus_gH2AX_std_edge
# nucleus_Phalloidin_std_edge
# nucleus_DAPI_max_edge
# nucleus_Ki-67_max_edge
# nucleus_COXIV_max_edge
# nucleus_Caspase-3_max_edge
# nucleus_WGA_max_edge
# nucleus_aTubulin_max_edge
# nucleus_Vimentin_max_edge
# nucleus_gH2AX_max_edge
# nucleus_Phalloidin_max_edge
# nucleus_DAPI_min_edge
# nucleus_Ki-67_min_edge
# nucleus_COXIV_min_edge
# nucleus_Caspase-3_min_edge
# nucleus_WGA_min_edge
# nucleus_aTubulin_min_edge
# nucleus_Vimentin_min_edge
# nucleus_gH2AX_min_edge
# nucleus_Phalloidin_min_edge
# nucleus_DAPI_mass_displacement
# nucleus_Ki-67_mass_displacement
# nucleus_COXIV_mass_displacement
# nucleus_Caspase-3_mass_displacement
# nucleus_WGA_mass_displacement
# nucleus_aTubulin_mass_displacement
# nucleus_Vimentin_mass_displacement
# nucleus_gH2AX_mass_displacement
# nucleus_Phalloidin_mass_displacement
# nucleus_DAPI_lower_quartile
# nucleus_Ki-67_lower_quartile
# nucleus_COXIV_lower_quartile
# nucleus_Caspase-3_lower_quartile
# nucleus_WGA_lower_quartile
# nucleus_aTubulin_lower_quartile
# nucleus_Vimentin_lower_quartile
# nucleus_gH2AX_lower_quartile
# nucleus_Phalloidin_lower_quartile
# nucleus_DAPI_median
# nucleus_Ki-67_median
# nucleus_COXIV_median
# nucleus_Caspase-3_median
# nucleus_WGA_median
# nucleus_aTubulin_median
# nucleus_Vimentin_median
# nucleus_gH2AX_median
# nucleus_Phalloidin_median
# nucleus_DAPI_mad
# nucleus_Ki-67_mad
# nucleus_COXIV_mad
# nucleus_Caspase-3_mad
# nucleus_WGA_mad
# nucleus_aTubulin_mad
# nucleus_Vimentin_mad
# nucleus_gH2AX_mad
# nucleus_Phalloidin_mad
# nucleus_DAPI_upper_quartile
# nucleus_Ki-67_upper_quartile
# nucleus_COXIV_upper_quartile
# nucleus_Caspase-3_upper_quartile
# nucleus_WGA_upper_quartile
# nucleus_aTubulin_upper_quartile
# nucleus_Vimentin_upper_quartile
# nucleus_gH2AX_upper_quartile
# nucleus_Phalloidin_upper_quartile
# nucleus_DAPI_center_mass_r
# nucleus_Ki-67_center_mass_r
# nucleus_COXIV_center_mass_r
# nucleus_Caspase-3_center_mass_r
# nucleus_WGA_center_mass_r
# nucleus_aTubulin_center_mass_r
# nucleus_Vimentin_center_mass_r
# nucleus_gH2AX_center_mass_r
# nucleus_Phalloidin_center_mass_r
# nucleus_DAPI_center_mass_c
# nucleus_Ki-67_center_mass_c
# nucleus_COXIV_center_mass_c
# nucleus_Caspase-3_center_mass_c
# nucleus_WGA_center_mass_c
# nucleus_aTubulin_center_mass_c
# nucleus_Vimentin_center_mass_c
# nucleus_gH2AX_center_mass_c
# nucleus_Phalloidin_center_mass_c
# nucleus_DAPI_max_location_r
# nucleus_Ki-67_max_location_r
# nucleus_COXIV_max_location_r
# nucleus_Caspase-3_max_location_r
# nucleus_WGA_max_location_r
# nucleus_aTubulin_max_location_r
# nucleus_Vimentin_max_location_r
# nucleus_gH2AX_max_location_r
# nucleus_Phalloidin_max_location_r
# nucleus_DAPI_max_location_c
# nucleus_Ki-67_max_location_c
# nucleus_COXIV_max_location_c
# nucleus_Caspase-3_max_location_c
# nucleus_WGA_max_location_c
# nucleus_aTubulin_max_location_c
# nucleus_Vimentin_max_location_c
# nucleus_gH2AX_max_location_c
# nucleus_Phalloidin_max_location_c
# nucleus_DAPI_frac_at_d_0
# nucleus_Ki-67_frac_at_d_0
# nucleus_COXIV_frac_at_d_0
# nucleus_Caspase-3_frac_at_d_0
# nucleus_WGA_frac_at_d_0
# nucleus_aTubulin_frac_at_d_0
# nucleus_Vimentin_frac_at_d_0
# nucleus_gH2AX_frac_at_d_0
# nucleus_Phalloidin_frac_at_d_0
# nucleus_DAPI_frac_at_d_1
# nucleus_Ki-67_frac_at_d_1
# nucleus_COXIV_frac_at_d_1
# nucleus_Caspase-3_frac_at_d_1
# nucleus_WGA_frac_at_d_1
# nucleus_aTubulin_frac_at_d_1
# nucleus_Vimentin_frac_at_d_1
# nucleus_gH2AX_frac_at_d_1
# nucleus_Phalloidin_frac_at_d_1
# nucleus_DAPI_frac_at_d_2
# nucleus_Ki-67_frac_at_d_2
# nucleus_COXIV_frac_at_d_2
# nucleus_Caspase-3_frac_at_d_2
# nucleus_WGA_frac_at_d_2
# nucleus_aTubulin_frac_at_d_2
# nucleus_Vimentin_frac_at_d_2
# nucleus_gH2AX_frac_at_d_2
# nucleus_Phalloidin_frac_at_d_2
# nucleus_DAPI_frac_at_d_3
# nucleus_Ki-67_frac_at_d_3
# nucleus_COXIV_frac_at_d_3
# nucleus_Caspase-3_frac_at_d_3
# nucleus_WGA_frac_at_d_3
# nucleus_aTubulin_frac_at_d_3
# nucleus_Vimentin_frac_at_d_3
# nucleus_gH2AX_frac_at_d_3
# nucleus_Phalloidin_frac_at_d_3
# nucleus_DAPI_mean_frac_0
# nucleus_Ki-67_mean_frac_0
# nucleus_COXIV_mean_frac_0
# nucleus_Caspase-3_mean_frac_0
# nucleus_WGA_mean_frac_0
# nucleus_aTubulin_mean_frac_0
# nucleus_Vimentin_mean_frac_0
# nucleus_gH2AX_mean_frac_0
# nucleus_Phalloidin_mean_frac_0
# nucleus_DAPI_mean_frac_1
# nucleus_Ki-67_mean_frac_1
# nucleus_COXIV_mean_frac_1
# nucleus_Caspase-3_mean_frac_1
# nucleus_WGA_mean_frac_1
# nucleus_aTubulin_mean_frac_1
# nucleus_Vimentin_mean_frac_1
# nucleus_gH2AX_mean_frac_1
# nucleus_Phalloidin_mean_frac_1
# nucleus_DAPI_mean_frac_2
# nucleus_Ki-67_mean_frac_2
# nucleus_COXIV_mean_frac_2
# nucleus_Caspase-3_mean_frac_2
# nucleus_WGA_mean_frac_2
# nucleus_aTubulin_mean_frac_2
# nucleus_Vimentin_mean_frac_2
# nucleus_gH2AX_mean_frac_2
# nucleus_Phalloidin_mean_frac_2
# nucleus_DAPI_mean_frac_3
# nucleus_Ki-67_mean_frac_3
# nucleus_COXIV_mean_frac_3
# nucleus_Caspase-3_mean_frac_3
# nucleus_WGA_mean_frac_3
# nucleus_aTubulin_mean_frac_3
# nucleus_Vimentin_mean_frac_3
# nucleus_gH2AX_mean_frac_3
# nucleus_Phalloidin_mean_frac_3
# nucleus_DAPI_radial_cv_0
# nucleus_Ki-67_radial_cv_0
# nucleus_COXIV_radial_cv_0
# nucleus_Caspase-3_radial_cv_0
# nucleus_WGA_radial_cv_0
# nucleus_aTubulin_radial_cv_0
# nucleus_Vimentin_radial_cv_0
# nucleus_gH2AX_radial_cv_0
# nucleus_Phalloidin_radial_cv_0
# nucleus_DAPI_radial_cv_1
# nucleus_Ki-67_radial_cv_1
# nucleus_COXIV_radial_cv_1
# nucleus_Caspase-3_radial_cv_1
# nucleus_WGA_radial_cv_1
# nucleus_aTubulin_radial_cv_1
# nucleus_Vimentin_radial_cv_1
# nucleus_gH2AX_radial_cv_1
# nucleus_Phalloidin_radial_cv_1
# nucleus_DAPI_radial_cv_2
# nucleus_Ki-67_radial_cv_2
# nucleus_COXIV_radial_cv_2
# nucleus_Caspase-3_radial_cv_2
# nucleus_WGA_radial_cv_2
# nucleus_aTubulin_radial_cv_2
# nucleus_Vimentin_radial_cv_2
# nucleus_gH2AX_radial_cv_2
# nucleus_Phalloidin_radial_cv_2
# nucleus_DAPI_radial_cv_3
# nucleus_Ki-67_radial_cv_3
# nucleus_COXIV_radial_cv_3
# nucleus_Caspase-3_radial_cv_3
# nucleus_WGA_radial_cv_3
# nucleus_aTubulin_radial_cv_3
# nucleus_Vimentin_radial_cv_3
# nucleus_gH2AX_radial_cv_3
# nucleus_Phalloidin_radial_cv_3
# nucleus_DAPI_weighted_hu_moments_0
# nucleus_Ki-67_weighted_hu_moments_0
# nucleus_COXIV_weighted_hu_moments_0
# nucleus_Caspase-3_weighted_hu_moments_0
# nucleus_WGA_weighted_hu_moments_0
# nucleus_aTubulin_weighted_hu_moments_0
# nucleus_Vimentin_weighted_hu_moments_0
# nucleus_gH2AX_weighted_hu_moments_0
# nucleus_Phalloidin_weighted_hu_moments_0
# nucleus_DAPI_weighted_hu_moments_1
# nucleus_Ki-67_weighted_hu_moments_1
# nucleus_COXIV_weighted_hu_moments_1
# nucleus_Caspase-3_weighted_hu_moments_1
# nucleus_WGA_weighted_hu_moments_1
# nucleus_aTubulin_weighted_hu_moments_1
# nucleus_Vimentin_weighted_hu_moments_1
# nucleus_gH2AX_weighted_hu_moments_1
# nucleus_Phalloidin_weighted_hu_moments_1
# nucleus_DAPI_weighted_hu_moments_2
# nucleus_Ki-67_weighted_hu_moments_2
# nucleus_COXIV_weighted_hu_moments_2
# nucleus_Caspase-3_weighted_hu_moments_2
# nucleus_WGA_weighted_hu_moments_2
# nucleus_aTubulin_weighted_hu_moments_2
# nucleus_Vimentin_weighted_hu_moments_2
# nucleus_gH2AX_weighted_hu_moments_2
# nucleus_Phalloidin_weighted_hu_moments_2
# nucleus_DAPI_weighted_hu_moments_3
# nucleus_Ki-67_weighted_hu_moments_3
# nucleus_COXIV_weighted_hu_moments_3
# nucleus_Caspase-3_weighted_hu_moments_3
# nucleus_WGA_weighted_hu_moments_3
# nucleus_aTubulin_weighted_hu_moments_3
# nucleus_Vimentin_weighted_hu_moments_3
# nucleus_gH2AX_weighted_hu_moments_3
# nucleus_Phalloidin_weighted_hu_moments_3
# nucleus_DAPI_weighted_hu_moments_4
# nucleus_Ki-67_weighted_hu_moments_4
# nucleus_COXIV_weighted_hu_moments_4
# nucleus_Caspase-3_weighted_hu_moments_4
# nucleus_WGA_weighted_hu_moments_4
# nucleus_aTubulin_weighted_hu_moments_4
# nucleus_Vimentin_weighted_hu_moments_4
# nucleus_gH2AX_weighted_hu_moments_4
# nucleus_Phalloidin_weighted_hu_moments_4
# nucleus_DAPI_weighted_hu_moments_5
# nucleus_Ki-67_weighted_hu_moments_5
# nucleus_COXIV_weighted_hu_moments_5
# nucleus_Caspase-3_weighted_hu_moments_5
# nucleus_WGA_weighted_hu_moments_5
# nucleus_aTubulin_weighted_hu_moments_5
# nucleus_Vimentin_weighted_hu_moments_5
# nucleus_gH2AX_weighted_hu_moments_5
# nucleus_Phalloidin_weighted_hu_moments_5
# nucleus_DAPI_weighted_hu_moments_6
# nucleus_Ki-67_weighted_hu_moments_6
# nucleus_COXIV_weighted_hu_moments_6
# nucleus_Caspase-3_weighted_hu_moments_6
# nucleus_WGA_weighted_hu_moments_6
# nucleus_aTubulin_weighted_hu_moments_6
# nucleus_Vimentin_weighted_hu_moments_6
# nucleus_gH2AX_weighted_hu_moments_6
# nucleus_Phalloidin_weighted_hu_moments_6
# nucleus_DAPI_pftas_0
# nucleus_Ki-67_pftas_0
# nucleus_COXIV_pftas_0
# nucleus_Caspase-3_pftas_0
# nucleus_WGA_pftas_0
# nucleus_aTubulin_pftas_0
# nucleus_Vimentin_pftas_0
# nucleus_gH2AX_pftas_0
# nucleus_Phalloidin_pftas_0
# nucleus_DAPI_pftas_1
# nucleus_Ki-67_pftas_1
# nucleus_COXIV_pftas_1
# nucleus_Caspase-3_pftas_1
# nucleus_WGA_pftas_1
# nucleus_aTubulin_pftas_1
# nucleus_Vimentin_pftas_1
# nucleus_gH2AX_pftas_1
# nucleus_Phalloidin_pftas_1
# nucleus_DAPI_pftas_2
# nucleus_Ki-67_pftas_2
# nucleus_COXIV_pftas_2
# nucleus_Caspase-3_pftas_2
# nucleus_WGA_pftas_2
# nucleus_aTubulin_pftas_2
# nucleus_Vimentin_pftas_2
# nucleus_gH2AX_pftas_2
# nucleus_Phalloidin_pftas_2
# nucleus_DAPI_pftas_3
# nucleus_Ki-67_pftas_3
# nucleus_COXIV_pftas_3
# nucleus_Caspase-3_pftas_3
# nucleus_WGA_pftas_3
# nucleus_aTubulin_pftas_3
# nucleus_Vimentin_pftas_3
# nucleus_gH2AX_pftas_3
# nucleus_Phalloidin_pftas_3
# nucleus_DAPI_pftas_4
# nucleus_Ki-67_pftas_4
# nucleus_COXIV_pftas_4
# nucleus_Caspase-3_pftas_4
# nucleus_WGA_pftas_4
# nucleus_aTubulin_pftas_4
# nucleus_Vimentin_pftas_4
# nucleus_gH2AX_pftas_4
# nucleus_Phalloidin_pftas_4
# nucleus_DAPI_pftas_5
# nucleus_Ki-67_pftas_5
# nucleus_COXIV_pftas_5
# nucleus_Caspase-3_pftas_5
# nucleus_WGA_pftas_5
# nucleus_aTubulin_pftas_5
# nucleus_Vimentin_pftas_5
# nucleus_gH2AX_pftas_5
# nucleus_Phalloidin_pftas_5
# nucleus_DAPI_pftas_6
# nucleus_Ki-67_pftas_6
# nucleus_COXIV_pftas_6
# nucleus_Caspase-3_pftas_6
# nucleus_WGA_pftas_6
# nucleus_aTubulin_pftas_6
# nucleus_Vimentin_pftas_6
# nucleus_gH2AX_pftas_6
# nucleus_Phalloidin_pftas_6
# nucleus_DAPI_pftas_7
# nucleus_Ki-67_pftas_7
# nucleus_COXIV_pftas_7
# nucleus_Caspase-3_pftas_7
# nucleus_WGA_pftas_7
# nucleus_aTubulin_pftas_7
# nucleus_Vimentin_pftas_7
# nucleus_gH2AX_pftas_7
# nucleus_Phalloidin_pftas_7
# nucleus_DAPI_pftas_8
# nucleus_Ki-67_pftas_8
# nucleus_COXIV_pftas_8
# nucleus_Caspase-3_pftas_8
# nucleus_WGA_pftas_8
# nucleus_aTubulin_pftas_8
# nucleus_Vimentin_pftas_8
# nucleus_gH2AX_pftas_8
# nucleus_Phalloidin_pftas_8
# nucleus_DAPI_pftas_9
# nucleus_Ki-67_pftas_9
# nucleus_COXIV_pftas_9
# nucleus_Caspase-3_pftas_9
# nucleus_WGA_pftas_9
# nucleus_aTubulin_pftas_9
# nucleus_Vimentin_pftas_9
# nucleus_gH2AX_pftas_9
# nucleus_Phalloidin_pftas_9
# nucleus_DAPI_pftas_10
# nucleus_Ki-67_pftas_10
# nucleus_COXIV_pftas_10
# nucleus_Caspase-3_pftas_10
# nucleus_WGA_pftas_10
# nucleus_aTubulin_pftas_10
# nucleus_Vimentin_pftas_10
# nucleus_gH2AX_pftas_10
# nucleus_Phalloidin_pftas_10
# nucleus_DAPI_pftas_11
# nucleus_Ki-67_pftas_11
# nucleus_COXIV_pftas_11
# nucleus_Caspase-3_pftas_11
# nucleus_WGA_pftas_11
# nucleus_aTubulin_pftas_11
# nucleus_Vimentin_pftas_11
# nucleus_gH2AX_pftas_11
# nucleus_Phalloidin_pftas_11
# nucleus_DAPI_pftas_12
# nucleus_Ki-67_pftas_12
# nucleus_COXIV_pftas_12
# nucleus_Caspase-3_pftas_12
# nucleus_WGA_pftas_12
# nucleus_aTubulin_pftas_12
# nucleus_Vimentin_pftas_12
# nucleus_gH2AX_pftas_12
# nucleus_Phalloidin_pftas_12
# nucleus_DAPI_pftas_13
# nucleus_Ki-67_pftas_13
# nucleus_COXIV_pftas_13
# nucleus_Caspase-3_pftas_13
# nucleus_WGA_pftas_13
# nucleus_aTubulin_pftas_13
# nucleus_Vimentin_pftas_13
# nucleus_gH2AX_pftas_13
# nucleus_Phalloidin_pftas_13
# nucleus_DAPI_pftas_14
# nucleus_Ki-67_pftas_14
# nucleus_COXIV_pftas_14
# nucleus_Caspase-3_pftas_14
# nucleus_WGA_pftas_14
# nucleus_aTubulin_pftas_14
# nucleus_Vimentin_pftas_14
# nucleus_gH2AX_pftas_14
# nucleus_Phalloidin_pftas_14
# nucleus_DAPI_pftas_15
# nucleus_Ki-67_pftas_15
# nucleus_COXIV_pftas_15
# nucleus_Caspase-3_pftas_15
# nucleus_WGA_pftas_15
# nucleus_aTubulin_pftas_15
# nucleus_Vimentin_pftas_15
# nucleus_gH2AX_pftas_15
# nucleus_Phalloidin_pftas_15
# nucleus_DAPI_pftas_16
# nucleus_Ki-67_pftas_16
# nucleus_COXIV_pftas_16
# nucleus_Caspase-3_pftas_16
# nucleus_WGA_pftas_16
# nucleus_aTubulin_pftas_16
# nucleus_Vimentin_pftas_16
# nucleus_gH2AX_pftas_16
# nucleus_Phalloidin_pftas_16
# nucleus_DAPI_pftas_17
# nucleus_Ki-67_pftas_17
# nucleus_COXIV_pftas_17
# nucleus_Caspase-3_pftas_17
# nucleus_WGA_pftas_17
# nucleus_aTubulin_pftas_17
# nucleus_Vimentin_pftas_17
# nucleus_gH2AX_pftas_17
# nucleus_Phalloidin_pftas_17
# nucleus_DAPI_pftas_18
# nucleus_Ki-67_pftas_18
# nucleus_COXIV_pftas_18
# nucleus_Caspase-3_pftas_18
# nucleus_WGA_pftas_18
# nucleus_aTubulin_pftas_18
# nucleus_Vimentin_pftas_18
# nucleus_gH2AX_pftas_18
# nucleus_Phalloidin_pftas_18
# nucleus_DAPI_pftas_19
# nucleus_Ki-67_pftas_19
# nucleus_COXIV_pftas_19
# nucleus_Caspase-3_pftas_19
# nucleus_WGA_pftas_19
# nucleus_aTubulin_pftas_19
# nucleus_Vimentin_pftas_19
# nucleus_gH2AX_pftas_19
# nucleus_Phalloidin_pftas_19
# nucleus_DAPI_pftas_20
# nucleus_Ki-67_pftas_20
# nucleus_COXIV_pftas_20
# nucleus_Caspase-3_pftas_20
# nucleus_WGA_pftas_20
# nucleus_aTubulin_pftas_20
# nucleus_Vimentin_pftas_20
# nucleus_gH2AX_pftas_20
# nucleus_Phalloidin_pftas_20
# nucleus_DAPI_pftas_21
# nucleus_Ki-67_pftas_21
# nucleus_COXIV_pftas_21
# nucleus_Caspase-3_pftas_21
# nucleus_WGA_pftas_21
# nucleus_aTubulin_pftas_21
# nucleus_Vimentin_pftas_21
# nucleus_gH2AX_pftas_21
# nucleus_Phalloidin_pftas_21
# nucleus_DAPI_pftas_22
# nucleus_Ki-67_pftas_22
# nucleus_COXIV_pftas_22
# nucleus_Caspase-3_pftas_22
# nucleus_WGA_pftas_22
# nucleus_aTubulin_pftas_22
# nucleus_Vimentin_pftas_22
# nucleus_gH2AX_pftas_22
# nucleus_Phalloidin_pftas_22
# nucleus_DAPI_pftas_23
# nucleus_Ki-67_pftas_23
# nucleus_COXIV_pftas_23
# nucleus_Caspase-3_pftas_23
# nucleus_WGA_pftas_23
# nucleus_aTubulin_pftas_23
# nucleus_Vimentin_pftas_23
# nucleus_gH2AX_pftas_23
# nucleus_Phalloidin_pftas_23
# nucleus_DAPI_pftas_24
# nucleus_Ki-67_pftas_24
# nucleus_COXIV_pftas_24
# nucleus_Caspase-3_pftas_24
# nucleus_WGA_pftas_24
# nucleus_aTubulin_pftas_24
# nucleus_Vimentin_pftas_24
# nucleus_gH2AX_pftas_24
# nucleus_Phalloidin_pftas_24
# nucleus_DAPI_pftas_25
# nucleus_Ki-67_pftas_25
# nucleus_COXIV_pftas_25
# nucleus_Caspase-3_pftas_25
# nucleus_WGA_pftas_25
# nucleus_aTubulin_pftas_25
# nucleus_Vimentin_pftas_25
# nucleus_gH2AX_pftas_25
# nucleus_Phalloidin_pftas_25
# nucleus_DAPI_pftas_26
# nucleus_Ki-67_pftas_26
# nucleus_COXIV_pftas_26
# nucleus_Caspase-3_pftas_26
# nucleus_WGA_pftas_26
# nucleus_aTubulin_pftas_26
# nucleus_Vimentin_pftas_26
# nucleus_gH2AX_pftas_26
# nucleus_Phalloidin_pftas_26
# nucleus_DAPI_pftas_27
# nucleus_Ki-67_pftas_27
# nucleus_COXIV_pftas_27
# nucleus_Caspase-3_pftas_27
# nucleus_WGA_pftas_27
# nucleus_aTubulin_pftas_27
# nucleus_Vimentin_pftas_27
# nucleus_gH2AX_pftas_27
# nucleus_Phalloidin_pftas_27
# nucleus_DAPI_pftas_28
# nucleus_Ki-67_pftas_28
# nucleus_COXIV_pftas_28
# nucleus_Caspase-3_pftas_28
# nucleus_WGA_pftas_28
# nucleus_aTubulin_pftas_28
# nucleus_Vimentin_pftas_28
# nucleus_gH2AX_pftas_28
# nucleus_Phalloidin_pftas_28
# nucleus_DAPI_pftas_29
# nucleus_Ki-67_pftas_29
# nucleus_COXIV_pftas_29
# nucleus_Caspase-3_pftas_29
# nucleus_WGA_pftas_29
# nucleus_aTubulin_pftas_29
# nucleus_Vimentin_pftas_29
# nucleus_gH2AX_pftas_29
# nucleus_Phalloidin_pftas_29
# nucleus_DAPI_pftas_30
# nucleus_Ki-67_pftas_30
# nucleus_COXIV_pftas_30
# nucleus_Caspase-3_pftas_30
# nucleus_WGA_pftas_30
# nucleus_aTubulin_pftas_30
# nucleus_Vimentin_pftas_30
# nucleus_gH2AX_pftas_30
# nucleus_Phalloidin_pftas_30
# nucleus_DAPI_pftas_31
# nucleus_Ki-67_pftas_31
# nucleus_COXIV_pftas_31
# nucleus_Caspase-3_pftas_31
# nucleus_WGA_pftas_31
# nucleus_aTubulin_pftas_31
# nucleus_Vimentin_pftas_31
# nucleus_gH2AX_pftas_31
# nucleus_Phalloidin_pftas_31
# nucleus_DAPI_pftas_32
# nucleus_Ki-67_pftas_32
# nucleus_COXIV_pftas_32
# nucleus_Caspase-3_pftas_32
# nucleus_WGA_pftas_32
# nucleus_aTubulin_pftas_32
# nucleus_Vimentin_pftas_32
# nucleus_gH2AX_pftas_32
# nucleus_Phalloidin_pftas_32
# nucleus_DAPI_pftas_33
# nucleus_Ki-67_pftas_33
# nucleus_COXIV_pftas_33
# nucleus_Caspase-3_pftas_33
# nucleus_WGA_pftas_33
# nucleus_aTubulin_pftas_33
# nucleus_Vimentin_pftas_33
# nucleus_gH2AX_pftas_33
# nucleus_Phalloidin_pftas_33
# nucleus_DAPI_pftas_34
# nucleus_Ki-67_pftas_34
# nucleus_COXIV_pftas_34
# nucleus_Caspase-3_pftas_34
# nucleus_WGA_pftas_34
# nucleus_aTubulin_pftas_34
# nucleus_Vimentin_pftas_34
# nucleus_gH2AX_pftas_34
# nucleus_Phalloidin_pftas_34
# nucleus_DAPI_pftas_35
# nucleus_Ki-67_pftas_35
# nucleus_COXIV_pftas_35
# nucleus_Caspase-3_pftas_35
# nucleus_WGA_pftas_35
# nucleus_aTubulin_pftas_35
# nucleus_Vimentin_pftas_35
# nucleus_gH2AX_pftas_35
# nucleus_Phalloidin_pftas_35
# nucleus_DAPI_pftas_36
# nucleus_Ki-67_pftas_36
# nucleus_COXIV_pftas_36
# nucleus_Caspase-3_pftas_36
# nucleus_WGA_pftas_36
# nucleus_aTubulin_pftas_36
# nucleus_Vimentin_pftas_36
# nucleus_gH2AX_pftas_36
# nucleus_Phalloidin_pftas_36
# nucleus_DAPI_pftas_37
# nucleus_Ki-67_pftas_37
# nucleus_COXIV_pftas_37
# nucleus_Caspase-3_pftas_37
# nucleus_WGA_pftas_37
# nucleus_aTubulin_pftas_37
# nucleus_Vimentin_pftas_37
# nucleus_gH2AX_pftas_37
# nucleus_Phalloidin_pftas_37
# nucleus_DAPI_pftas_38
# nucleus_Ki-67_pftas_38
# nucleus_COXIV_pftas_38
# nucleus_Caspase-3_pftas_38
# nucleus_WGA_pftas_38
# nucleus_aTubulin_pftas_38
# nucleus_Vimentin_pftas_38
# nucleus_gH2AX_pftas_38
# nucleus_Phalloidin_pftas_38
# nucleus_DAPI_pftas_39
# nucleus_Ki-67_pftas_39
# nucleus_COXIV_pftas_39
# nucleus_Caspase-3_pftas_39
# nucleus_WGA_pftas_39
# nucleus_aTubulin_pftas_39
# nucleus_Vimentin_pftas_39
# nucleus_gH2AX_pftas_39
# nucleus_Phalloidin_pftas_39
# nucleus_DAPI_pftas_40
# nucleus_Ki-67_pftas_40
# nucleus_COXIV_pftas_40
# nucleus_Caspase-3_pftas_40
# nucleus_WGA_pftas_40
# nucleus_aTubulin_pftas_40
# nucleus_Vimentin_pftas_40
# nucleus_gH2AX_pftas_40
# nucleus_Phalloidin_pftas_40
# nucleus_DAPI_pftas_41
# nucleus_Ki-67_pftas_41
# nucleus_COXIV_pftas_41
# nucleus_Caspase-3_pftas_41
# nucleus_WGA_pftas_41
# nucleus_aTubulin_pftas_41
# nucleus_Vimentin_pftas_41
# nucleus_gH2AX_pftas_41
# nucleus_Phalloidin_pftas_41
# nucleus_DAPI_pftas_42
# nucleus_Ki-67_pftas_42
# nucleus_COXIV_pftas_42
# nucleus_Caspase-3_pftas_42
# nucleus_WGA_pftas_42
# nucleus_aTubulin_pftas_42
# nucleus_Vimentin_pftas_42
# nucleus_gH2AX_pftas_42
# nucleus_Phalloidin_pftas_42
# nucleus_DAPI_pftas_43
# nucleus_Ki-67_pftas_43
# nucleus_COXIV_pftas_43
# nucleus_Caspase-3_pftas_43
# nucleus_WGA_pftas_43
# nucleus_aTubulin_pftas_43
# nucleus_Vimentin_pftas_43
# nucleus_gH2AX_pftas_43
# nucleus_Phalloidin_pftas_43
# nucleus_DAPI_pftas_44
# nucleus_Ki-67_pftas_44
# nucleus_COXIV_pftas_44
# nucleus_Caspase-3_pftas_44
# nucleus_WGA_pftas_44
# nucleus_aTubulin_pftas_44
# nucleus_Vimentin_pftas_44
# nucleus_gH2AX_pftas_44
# nucleus_Phalloidin_pftas_44
# nucleus_DAPI_pftas_45
# nucleus_Ki-67_pftas_45
# nucleus_COXIV_pftas_45
# nucleus_Caspase-3_pftas_45
# nucleus_WGA_pftas_45
# nucleus_aTubulin_pftas_45
# nucleus_Vimentin_pftas_45
# nucleus_gH2AX_pftas_45
# nucleus_Phalloidin_pftas_45
# nucleus_DAPI_pftas_46
# nucleus_Ki-67_pftas_46
# nucleus_COXIV_pftas_46
# nucleus_Caspase-3_pftas_46
# nucleus_WGA_pftas_46
# nucleus_aTubulin_pftas_46
# nucleus_Vimentin_pftas_46
# nucleus_gH2AX_pftas_46
# nucleus_Phalloidin_pftas_46
# nucleus_DAPI_pftas_47
# nucleus_Ki-67_pftas_47
# nucleus_COXIV_pftas_47
# nucleus_Caspase-3_pftas_47
# nucleus_WGA_pftas_47
# nucleus_aTubulin_pftas_47
# nucleus_Vimentin_pftas_47
# nucleus_gH2AX_pftas_47
# nucleus_Phalloidin_pftas_47
# nucleus_DAPI_pftas_48
# nucleus_Ki-67_pftas_48
# nucleus_COXIV_pftas_48
# nucleus_Caspase-3_pftas_48
# nucleus_WGA_pftas_48
# nucleus_aTubulin_pftas_48
# nucleus_Vimentin_pftas_48
# nucleus_gH2AX_pftas_48
# nucleus_Phalloidin_pftas_48
# nucleus_DAPI_pftas_49
# nucleus_Ki-67_pftas_49
# nucleus_COXIV_pftas_49
# nucleus_Caspase-3_pftas_49
# nucleus_WGA_pftas_49
# nucleus_aTubulin_pftas_49
# nucleus_Vimentin_pftas_49
# nucleus_gH2AX_pftas_49
# nucleus_Phalloidin_pftas_49
# nucleus_DAPI_pftas_50
# nucleus_Ki-67_pftas_50
# nucleus_COXIV_pftas_50
# nucleus_Caspase-3_pftas_50
# nucleus_WGA_pftas_50
# nucleus_aTubulin_pftas_50
# nucleus_Vimentin_pftas_50
# nucleus_gH2AX_pftas_50
# nucleus_Phalloidin_pftas_50
# nucleus_DAPI_pftas_51
# nucleus_Ki-67_pftas_51
# nucleus_COXIV_pftas_51
# nucleus_Caspase-3_pftas_51
# nucleus_WGA_pftas_51
# nucleus_aTubulin_pftas_51
# nucleus_Vimentin_pftas_51
# nucleus_gH2AX_pftas_51
# nucleus_Phalloidin_pftas_51
# nucleus_DAPI_pftas_52
# nucleus_Ki-67_pftas_52
# nucleus_COXIV_pftas_52
# nucleus_Caspase-3_pftas_52
# nucleus_WGA_pftas_52
# nucleus_aTubulin_pftas_52
# nucleus_Vimentin_pftas_52
# nucleus_gH2AX_pftas_52
# nucleus_Phalloidin_pftas_52
# nucleus_DAPI_pftas_53
# nucleus_Ki-67_pftas_53
# nucleus_COXIV_pftas_53
# nucleus_Caspase-3_pftas_53
# nucleus_WGA_pftas_53
# nucleus_aTubulin_pftas_53
# nucleus_Vimentin_pftas_53
# nucleus_gH2AX_pftas_53
# nucleus_Phalloidin_pftas_53
# nucleus_DAPI_haralick_5_0
# nucleus_Ki-67_haralick_5_0
# nucleus_COXIV_haralick_5_0
# nucleus_Caspase-3_haralick_5_0
# nucleus_WGA_haralick_5_0
# nucleus_aTubulin_haralick_5_0
# nucleus_Vimentin_haralick_5_0
# nucleus_gH2AX_haralick_5_0
# nucleus_Phalloidin_haralick_5_0
# nucleus_DAPI_haralick_5_1
# nucleus_Ki-67_haralick_5_1
# nucleus_COXIV_haralick_5_1
# nucleus_Caspase-3_haralick_5_1
# nucleus_WGA_haralick_5_1
# nucleus_aTubulin_haralick_5_1
# nucleus_Vimentin_haralick_5_1
# nucleus_gH2AX_haralick_5_1
# nucleus_Phalloidin_haralick_5_1
# nucleus_DAPI_haralick_5_2
# nucleus_Ki-67_haralick_5_2
# nucleus_COXIV_haralick_5_2
# nucleus_Caspase-3_haralick_5_2
# nucleus_WGA_haralick_5_2
# nucleus_aTubulin_haralick_5_2
# nucleus_Vimentin_haralick_5_2
# nucleus_gH2AX_haralick_5_2
# nucleus_Phalloidin_haralick_5_2
# nucleus_DAPI_haralick_5_3
# nucleus_Ki-67_haralick_5_3
# nucleus_COXIV_haralick_5_3
# nucleus_Caspase-3_haralick_5_3
# nucleus_WGA_haralick_5_3
# nucleus_aTubulin_haralick_5_3
# nucleus_Vimentin_haralick_5_3
# nucleus_gH2AX_haralick_5_3
# nucleus_Phalloidin_haralick_5_3
# nucleus_DAPI_haralick_5_4
# nucleus_Ki-67_haralick_5_4
# nucleus_COXIV_haralick_5_4
# nucleus_Caspase-3_haralick_5_4
# nucleus_WGA_haralick_5_4
# nucleus_aTubulin_haralick_5_4
# nucleus_Vimentin_haralick_5_4
# nucleus_gH2AX_haralick_5_4
# nucleus_Phalloidin_haralick_5_4
# nucleus_DAPI_haralick_5_5
# nucleus_Ki-67_haralick_5_5
# nucleus_COXIV_haralick_5_5
# nucleus_Caspase-3_haralick_5_5
# nucleus_WGA_haralick_5_5
# nucleus_aTubulin_haralick_5_5
# nucleus_Vimentin_haralick_5_5
# nucleus_gH2AX_haralick_5_5
# nucleus_Phalloidin_haralick_5_5
# nucleus_DAPI_haralick_5_6
# nucleus_Ki-67_haralick_5_6
# nucleus_COXIV_haralick_5_6
# nucleus_Caspase-3_haralick_5_6
# nucleus_WGA_haralick_5_6
# nucleus_aTubulin_haralick_5_6
# nucleus_Vimentin_haralick_5_6
# nucleus_gH2AX_haralick_5_6
# nucleus_Phalloidin_haralick_5_6
# nucleus_DAPI_haralick_5_7
# nucleus_Ki-67_haralick_5_7
# nucleus_COXIV_haralick_5_7
# nucleus_Caspase-3_haralick_5_7
# nucleus_WGA_haralick_5_7
# nucleus_aTubulin_haralick_5_7
# nucleus_Vimentin_haralick_5_7
# nucleus_gH2AX_haralick_5_7
# nucleus_Phalloidin_haralick_5_7
# nucleus_DAPI_haralick_5_8
# nucleus_Ki-67_haralick_5_8
# nucleus_COXIV_haralick_5_8
# nucleus_Caspase-3_haralick_5_8
# nucleus_WGA_haralick_5_8
# nucleus_aTubulin_haralick_5_8
# nucleus_Vimentin_haralick_5_8
# nucleus_gH2AX_haralick_5_8
# nucleus_Phalloidin_haralick_5_8
# nucleus_DAPI_haralick_5_9
# nucleus_Ki-67_haralick_5_9
# nucleus_COXIV_haralick_5_9
# nucleus_Caspase-3_haralick_5_9
# nucleus_WGA_haralick_5_9
# nucleus_aTubulin_haralick_5_9
# nucleus_Vimentin_haralick_5_9
# nucleus_gH2AX_haralick_5_9
# nucleus_Phalloidin_haralick_5_9
# nucleus_DAPI_haralick_5_10
# nucleus_Ki-67_haralick_5_10
# nucleus_COXIV_haralick_5_10
# nucleus_Caspase-3_haralick_5_10
# nucleus_WGA_haralick_5_10
# nucleus_aTubulin_haralick_5_10
# nucleus_Vimentin_haralick_5_10
# nucleus_gH2AX_haralick_5_10
# nucleus_Phalloidin_haralick_5_10
# nucleus_DAPI_haralick_5_11
# nucleus_Ki-67_haralick_5_11
# nucleus_COXIV_haralick_5_11
# nucleus_Caspase-3_haralick_5_11
# nucleus_WGA_haralick_5_11
# nucleus_aTubulin_haralick_5_11
# nucleus_Vimentin_haralick_5_11
# nucleus_gH2AX_haralick_5_11
# nucleus_Phalloidin_haralick_5_11
# nucleus_DAPI_haralick_5_12
# nucleus_Ki-67_haralick_5_12
# nucleus_COXIV_haralick_5_12
# nucleus_Caspase-3_haralick_5_12
# nucleus_WGA_haralick_5_12
# nucleus_aTubulin_haralick_5_12
# nucleus_Vimentin_haralick_5_12
# nucleus_gH2AX_haralick_5_12
# nucleus_Phalloidin_haralick_5_12
# nucleus_correlation_DAPI_Ki-67
# nucleus_correlation_DAPI_COXIV
# nucleus_correlation_DAPI_Caspase-3
# nucleus_correlation_DAPI_WGA
# nucleus_correlation_DAPI_aTubulin
# nucleus_correlation_DAPI_Vimentin
# nucleus_correlation_DAPI_gH2AX
# nucleus_correlation_DAPI_Phalloidin
# nucleus_correlation_Ki-67_COXIV
# nucleus_correlation_Ki-67_Caspase-3
# nucleus_correlation_Ki-67_WGA
# nucleus_correlation_Ki-67_aTubulin
# nucleus_correlation_Ki-67_Vimentin
# nucleus_correlation_Ki-67_gH2AX
# nucleus_correlation_Ki-67_Phalloidin
# nucleus_correlation_COXIV_Caspase-3
# nucleus_correlation_COXIV_WGA
# nucleus_correlation_COXIV_aTubulin
# nucleus_correlation_COXIV_Vimentin
# nucleus_correlation_COXIV_gH2AX
# nucleus_correlation_COXIV_Phalloidin
# nucleus_correlation_Caspase-3_WGA
# nucleus_correlation_Caspase-3_aTubulin
# nucleus_correlation_Caspase-3_Vimentin
# nucleus_correlation_Caspase-3_gH2AX
# nucleus_correlation_Caspase-3_Phalloidin
# nucleus_correlation_WGA_aTubulin
# nucleus_correlation_WGA_Vimentin
# nucleus_correlation_WGA_gH2AX
# nucleus_correlation_WGA_Phalloidin
# nucleus_correlation_aTubulin_Vimentin
# nucleus_correlation_aTubulin_gH2AX
# nucleus_correlation_aTubulin_Phalloidin
# nucleus_correlation_Vimentin_gH2AX
# nucleus_correlation_Vimentin_Phalloidin
# nucleus_correlation_gH2AX_Phalloidin
# nucleus_lstsq_slope_DAPI_Ki-67
# nucleus_lstsq_slope_DAPI_COXIV
# nucleus_lstsq_slope_DAPI_Caspase-3
# nucleus_lstsq_slope_DAPI_WGA
# nucleus_lstsq_slope_DAPI_aTubulin
# nucleus_lstsq_slope_DAPI_Vimentin
# nucleus_lstsq_slope_DAPI_gH2AX
# nucleus_lstsq_slope_DAPI_Phalloidin
# nucleus_lstsq_slope_Ki-67_DAPI
# nucleus_lstsq_slope_Ki-67_COXIV
# nucleus_lstsq_slope_Ki-67_Caspase-3
# nucleus_lstsq_slope_Ki-67_WGA
# nucleus_lstsq_slope_Ki-67_aTubulin
# nucleus_lstsq_slope_Ki-67_Vimentin
# nucleus_lstsq_slope_Ki-67_gH2AX
# nucleus_lstsq_slope_Ki-67_Phalloidin
# nucleus_lstsq_slope_COXIV_DAPI
# nucleus_lstsq_slope_COXIV_Ki-67
# nucleus_lstsq_slope_COXIV_Caspase-3
# nucleus_lstsq_slope_COXIV_WGA
# nucleus_lstsq_slope_COXIV_aTubulin
# nucleus_lstsq_slope_COXIV_Vimentin
# nucleus_lstsq_slope_COXIV_gH2AX
# nucleus_lstsq_slope_COXIV_Phalloidin
# nucleus_lstsq_slope_Caspase-3_DAPI
# nucleus_lstsq_slope_Caspase-3_Ki-67
# nucleus_lstsq_slope_Caspase-3_COXIV
# nucleus_lstsq_slope_Caspase-3_WGA
# nucleus_lstsq_slope_Caspase-3_aTubulin
# nucleus_lstsq_slope_Caspase-3_Vimentin
# nucleus_lstsq_slope_Caspase-3_gH2AX
# nucleus_lstsq_slope_Caspase-3_Phalloidin
# nucleus_lstsq_slope_WGA_DAPI
# nucleus_lstsq_slope_WGA_Ki-67
# nucleus_lstsq_slope_WGA_COXIV
# nucleus_lstsq_slope_WGA_Caspase-3
# nucleus_lstsq_slope_WGA_aTubulin
# nucleus_lstsq_slope_WGA_Vimentin
# nucleus_lstsq_slope_WGA_gH2AX
# nucleus_lstsq_slope_WGA_Phalloidin
# nucleus_lstsq_slope_aTubulin_DAPI
# nucleus_lstsq_slope_aTubulin_Ki-67
# nucleus_lstsq_slope_aTubulin_COXIV
# nucleus_lstsq_slope_aTubulin_Caspase-3
# nucleus_lstsq_slope_aTubulin_WGA
# nucleus_lstsq_slope_aTubulin_Vimentin
# nucleus_lstsq_slope_aTubulin_gH2AX
# nucleus_lstsq_slope_aTubulin_Phalloidin
# nucleus_lstsq_slope_Vimentin_DAPI
# nucleus_lstsq_slope_Vimentin_Ki-67
# nucleus_lstsq_slope_Vimentin_COXIV
# nucleus_lstsq_slope_Vimentin_Caspase-3
# nucleus_lstsq_slope_Vimentin_WGA
# nucleus_lstsq_slope_Vimentin_aTubulin
# nucleus_lstsq_slope_Vimentin_gH2AX
# nucleus_lstsq_slope_Vimentin_Phalloidin
# nucleus_lstsq_slope_gH2AX_DAPI
# nucleus_lstsq_slope_gH2AX_Ki-67
# nucleus_lstsq_slope_gH2AX_COXIV
# nucleus_lstsq_slope_gH2AX_Caspase-3
# nucleus_lstsq_slope_gH2AX_WGA
# nucleus_lstsq_slope_gH2AX_aTubulin
# nucleus_lstsq_slope_gH2AX_Vimentin
# nucleus_lstsq_slope_gH2AX_Phalloidin
# nucleus_lstsq_slope_Phalloidin_DAPI
# nucleus_lstsq_slope_Phalloidin_Ki-67
# nucleus_lstsq_slope_Phalloidin_COXIV
# nucleus_lstsq_slope_Phalloidin_Caspase-3
# nucleus_lstsq_slope_Phalloidin_WGA
# nucleus_lstsq_slope_Phalloidin_aTubulin
# nucleus_lstsq_slope_Phalloidin_Vimentin
# nucleus_lstsq_slope_Phalloidin_gH2AX
# nucleus_overlap_DAPI_Ki-67
# nucleus_overlap_DAPI_COXIV
# nucleus_overlap_DAPI_Caspase-3
# nucleus_overlap_DAPI_WGA
# nucleus_overlap_DAPI_aTubulin
# nucleus_overlap_DAPI_Vimentin
# nucleus_overlap_DAPI_gH2AX
# nucleus_overlap_DAPI_Phalloidin
# nucleus_overlap_Ki-67_COXIV
# nucleus_overlap_Ki-67_Caspase-3
# nucleus_overlap_Ki-67_WGA
# nucleus_overlap_Ki-67_aTubulin
# nucleus_overlap_Ki-67_Vimentin
# nucleus_overlap_Ki-67_gH2AX
# nucleus_overlap_Ki-67_Phalloidin
# nucleus_overlap_COXIV_Caspase-3
# nucleus_overlap_COXIV_WGA
# nucleus_overlap_COXIV_aTubulin
# nucleus_overlap_COXIV_Vimentin
# nucleus_overlap_COXIV_gH2AX
# nucleus_overlap_COXIV_Phalloidin
# nucleus_overlap_Caspase-3_WGA
# nucleus_overlap_Caspase-3_aTubulin
# nucleus_overlap_Caspase-3_Vimentin
# nucleus_overlap_Caspase-3_gH2AX
# nucleus_overlap_Caspase-3_Phalloidin
# nucleus_overlap_WGA_aTubulin
# nucleus_overlap_WGA_Vimentin
# nucleus_overlap_WGA_gH2AX
# nucleus_overlap_WGA_Phalloidin
# nucleus_overlap_aTubulin_Vimentin
# nucleus_overlap_aTubulin_gH2AX
# nucleus_overlap_aTubulin_Phalloidin
# nucleus_overlap_Vimentin_gH2AX
# nucleus_overlap_Vimentin_Phalloidin
# nucleus_overlap_gH2AX_Phalloidin
# nucleus_K_DAPI_Ki-67
# nucleus_K_DAPI_COXIV
# nucleus_K_DAPI_Caspase-3
# nucleus_K_DAPI_WGA
# nucleus_K_DAPI_aTubulin
# nucleus_K_DAPI_Vimentin
# nucleus_K_DAPI_gH2AX
# nucleus_K_DAPI_Phalloidin
# nucleus_K_Ki-67_COXIV
# nucleus_K_Ki-67_Caspase-3
# nucleus_K_Ki-67_WGA
# nucleus_K_Ki-67_aTubulin
# nucleus_K_Ki-67_Vimentin
# nucleus_K_Ki-67_gH2AX
# nucleus_K_Ki-67_Phalloidin
# nucleus_K_COXIV_Caspase-3
# nucleus_K_COXIV_WGA
# nucleus_K_COXIV_aTubulin
# nucleus_K_COXIV_Vimentin
# nucleus_K_COXIV_gH2AX
# nucleus_K_COXIV_Phalloidin
# nucleus_K_Caspase-3_WGA
# nucleus_K_Caspase-3_aTubulin
# nucleus_K_Caspase-3_Vimentin
# nucleus_K_Caspase-3_gH2AX
# nucleus_K_Caspase-3_Phalloidin
# nucleus_K_WGA_aTubulin
# nucleus_K_WGA_Vimentin
# nucleus_K_WGA_gH2AX
# nucleus_K_WGA_Phalloidin
# nucleus_K_aTubulin_Vimentin
# nucleus_K_aTubulin_gH2AX
# nucleus_K_aTubulin_Phalloidin
# nucleus_K_Vimentin_gH2AX
# nucleus_K_Vimentin_Phalloidin
# nucleus_K_gH2AX_Phalloidin
# nucleus_K_Ki-67_DAPI
# nucleus_K_COXIV_DAPI
# nucleus_K_Caspase-3_DAPI
# nucleus_K_WGA_DAPI
# nucleus_K_aTubulin_DAPI
# nucleus_K_Vimentin_DAPI
# nucleus_K_gH2AX_DAPI
# nucleus_manders_aTubulin_Ki-67
# nucleus_manders_Vimentin_Ki-67
# nucleus_manders_gH2AX_Ki-67
# nucleus_manders_Phalloidin_Ki-67
# nucleus_manders_Caspase-3_COXIV
# nucleus_manders_WGA_COXIV
# nucleus_manders_aTubulin_COXIV
# nucleus_manders_Vimentin_COXIV
# nucleus_manders_gH2AX_COXIV
# nucleus_manders_Phalloidin_COXIV
# nucleus_manders_WGA_Caspase-3
# nucleus_manders_aTubulin_Caspase-3
# nucleus_manders_Vimentin_Caspase-3
# nucleus_manders_gH2AX_Caspase-3
# nucleus_manders_Phalloidin_Caspase-3
# nucleus_manders_aTubulin_WGA
# nucleus_manders_Vimentin_WGA
# nucleus_manders_gH2AX_WGA
# nucleus_manders_Phalloidin_WGA
# nucleus_manders_Vimentin_aTubulin
# nucleus_manders_gH2AX_aTubulin
# nucleus_manders_Phalloidin_aTubulin
# nucleus_manders_gH2AX_Vimentin
# nucleus_manders_Phalloidin_Vimentin
# nucleus_manders_Phalloidin_gH2AX
# nucleus_rwc_DAPI_Ki-67
# nucleus_rwc_DAPI_COXIV
# nucleus_rwc_DAPI_Caspase-3
# nucleus_rwc_DAPI_WGA
# nucleus_rwc_DAPI_aTubulin
# nucleus_rwc_DAPI_Vimentin
# nucleus_rwc_DAPI_gH2AX
# nucleus_rwc_DAPI_Phalloidin
# nucleus_rwc_Ki-67_COXIV
# nucleus_rwc_Ki-67_Caspase-3
# nucleus_rwc_Ki-67_WGA
# nucleus_rwc_Ki-67_aTubulin
# nucleus_rwc_Ki-67_Vimentin
# nucleus_rwc_Ki-67_gH2AX
# nucleus_rwc_Ki-67_Phalloidin
# nucleus_rwc_COXIV_Caspase-3
# nucleus_rwc_COXIV_WGA
# nucleus_rwc_COXIV_aTubulin
# nucleus_rwc_COXIV_Vimentin
# nucleus_rwc_COXIV_gH2AX
# nucleus_rwc_COXIV_Phalloidin
# nucleus_rwc_Caspase-3_WGA
# nucleus_rwc_Caspase-3_aTubulin
# nucleus_rwc_Caspase-3_Vimentin
# nucleus_rwc_Caspase-3_gH2AX
# nucleus_rwc_Caspase-3_Phalloidin
# nucleus_rwc_WGA_aTubulin
# nucleus_rwc_WGA_Vimentin
# nucleus_rwc_WGA_gH2AX
# nucleus_rwc_WGA_Phalloidin
# nucleus_rwc_aTubulin_Vimentin
# nucleus_rwc_aTubulin_gH2AX
# nucleus_rwc_aTubulin_Phalloidin
# nucleus_rwc_Vimentin_gH2AX
# nucleus_rwc_Vimentin_Phalloidin
# nucleus_rwc_gH2AX_Phalloidin
# nucleus_rwc_Ki-67_DAPI
# nucleus_rwc_COXIV_DAPI
# nucleus_rwc_Caspase-3_DAPI
# nucleus_rwc_WGA_DAPI
# nucleus_rwc_aTubulin_DAPI
# nucleus_rwc_Vimentin_DAPI
# nucleus_rwc_gH2AX_DAPI
# nucleus_rwc_Phalloidin_DAPI
# nucleus_rwc_COXIV_Ki-67
# nucleus_rwc_Caspase-3_Ki-67
# nucleus_rwc_WGA_Ki-67
# nucleus_rwc_aTubulin_Ki-67
# nucleus_rwc_Vimentin_Ki-67
# nucleus_rwc_gH2AX_Ki-67
# nucleus_rwc_Phalloidin_Ki-67
# nucleus_rwc_Caspase-3_COXIV
# nucleus_rwc_WGA_COXIV
# nucleus_rwc_aTubulin_COXIV
# nucleus_rwc_Vimentin_COXIV
# nucleus_rwc_gH2AX_COXIV
# nucleus_rwc_Phalloidin_COXIV
# nucleus_rwc_WGA_Caspase-3
# nucleus_rwc_aTubulin_Caspase-3
# nucleus_rwc_Vimentin_Caspase-3
# nucleus_rwc_gH2AX_Caspase-3
# nucleus_rwc_Phalloidin_Caspase-3
# nucleus_rwc_aTubulin_WGA
# nucleus_rwc_Vimentin_WGA
# nucleus_rwc_gH2AX_WGA
# nucleus_rwc_Phalloidin_WGA
# nucleus_rwc_Vimentin_aTubulin
# nucleus_rwc_gH2AX_aTubulin
# nucleus_rwc_Phalloidin_aTubulin
# nucleus_rwc_gH2AX_Vimentin
# nucleus_rwc_Phalloidin_Vimentin
# nucleus_rwc_Phalloidin_gH2AX
# nucleus_area
# nucleus_perimeter
# nucleus_convex_area
# nucleus_form_factor
# nucleus_solidity
# nucleus_extent
# nucleus_euler_number
# nucleus_centroid_r
# nucleus_centroid_c
# nucleus_eccentricity
# nucleus_major_axis
# nucleus_minor_axis
# nucleus_orientation
# nucleus_compactness
# nucleus_max_radius
# nucleus_median_radius
# nucleus_mean_radius
# nucleus_min_feret_diameter
# nucleus_max_feret_diameter
# nucleus_min_feret_r0
# nucleus_min_feret_c0
# nucleus_min_feret_r1
# nucleus_min_feret_c1
# nucleus_max_feret_r0
# nucleus_max_feret_c0
# nucleus_max_feret_r1
# nucleus_max_feret_c1
# nucleus_hu_moments_0
# nucleus_hu_moments_1
# nucleus_hu_moments_2
# nucleus_hu_moments_3
# nucleus_hu_moments_4
# nucleus_hu_moments_5
# nucleus_hu_moments_6
# nucleus_zernike_0_0
# nucleus_zernike_1_1
# nucleus_zernike_2_0
# nucleus_zernike_2_2
# nucleus_zernike_3_1
# nucleus_zernike_3_3
# nucleus_zernike_4_0
# nucleus_zernike_4_2
# nucleus_zernike_4_4
# nucleus_zernike_5_1
# nucleus_zernike_5_3
# nucleus_zernike_5_5
# nucleus_zernike_6_0
# nucleus_zernike_6_2
# nucleus_zernike_6_4
# nucleus_zernike_6_6
# nucleus_zernike_7_1
# nucleus_zernike_7_3
# nucleus_zernike_7_5
# nucleus_zernike_7_7
# nucleus_zernike_8_0
# nucleus_zernike_8_2
# nucleus_zernike_8_4
# nucleus_zernike_8_6
# nucleus_zernike_8_8
# nucleus_zernike_9_1
# nucleus_zernike_9_3
# nucleus_zernike_9_5
# nucleus_zernike_9_7
# nucleus_zernike_9_9
# nucleus_number_neighbors_1
# nucleus_percent_touching_1
# nucleus_first_neighbor_distance
# nucleus_second_neighbor_distance
# nucleus_angle_between_neighbors
# cell_DAPI_int
# cell_Ki-67_int
# cell_COXIV_int
# cell_Caspase-3_int
# cell_WGA_int
# cell_aTubulin_int
# cell_Vimentin_int
# cell_gH2AX_int
# cell_Phalloidin_int
# cell_DAPI_mean
# cell_Ki-67_mean
# cell_COXIV_mean
# cell_Caspase-3_mean
# cell_WGA_mean
# cell_aTubulin_mean
# cell_Vimentin_mean
# cell_gH2AX_mean
# cell_Phalloidin_mean
# cell_DAPI_std
# cell_Ki-67_std
# cell_COXIV_std
# cell_Caspase-3_std
# cell_WGA_std
# cell_aTubulin_std
# cell_Vimentin_std
# cell_gH2AX_std
# cell_Phalloidin_std
# cell_DAPI_max
# cell_Ki-67_max
# cell_COXIV_max
# cell_Caspase-3_max
# cell_WGA_max
# cell_aTubulin_max
# cell_Vimentin_max
# cell_gH2AX_max
# cell_Phalloidin_max
# cell_DAPI_min
# cell_Ki-67_min
# cell_COXIV_min
# cell_Caspase-3_min
# cell_WGA_min
# cell_aTubulin_min
# cell_Vimentin_min
# cell_gH2AX_min
# cell_Phalloidin_min
# cell_DAPI_int_edge
# cell_Ki-67_int_edge
# cell_COXIV_int_edge
# cell_Caspase-3_int_edge
# cell_WGA_int_edge
# cell_aTubulin_int_edge
# cell_Vimentin_int_edge
# cell_gH2AX_int_edge
# cell_Phalloidin_int_edge
# cell_DAPI_mean_edge
# cell_Ki-67_mean_edge
# cell_COXIV_mean_edge
# cell_Caspase-3_mean_edge
# cell_WGA_mean_edge
# cell_aTubulin_mean_edge
# cell_Vimentin_mean_edge
# cell_gH2AX_mean_edge
# cell_Phalloidin_mean_edge
# cell_DAPI_std_edge
# cell_Ki-67_std_edge
# cell_COXIV_std_edge
# cell_Caspase-3_std_edge
# cell_WGA_std_edge
# cell_aTubulin_std_edge
# cell_Vimentin_std_edge
# cell_gH2AX_std_edge
# cell_Phalloidin_std_edge
# cell_DAPI_max_edge
# cell_Ki-67_max_edge
# cell_COXIV_max_edge
# cell_Caspase-3_max_edge
# cell_WGA_max_edge
# cell_aTubulin_max_edge
# cell_Vimentin_max_edge
# cell_gH2AX_max_edge
# cell_Phalloidin_max_edge
# cell_DAPI_min_edge
# cell_Ki-67_min_edge
# cell_COXIV_min_edge
# cell_Caspase-3_min_edge
# cell_WGA_min_edge
# cell_aTubulin_min_edge
# cell_Vimentin_min_edge
# cell_gH2AX_min_edge
# cell_Phalloidin_min_edge
# cell_DAPI_mass_displacement
# cell_Ki-67_mass_displacement
# cell_COXIV_mass_displacement
# cell_Caspase-3_mass_displacement
# cell_WGA_mass_displacement
# cell_aTubulin_mass_displacement
# cell_Vimentin_mass_displacement
# cell_gH2AX_mass_displacement
# cell_Phalloidin_mass_displacement
# cell_DAPI_lower_quartile
# cell_Ki-67_lower_quartile
# cell_COXIV_lower_quartile
# cell_Caspase-3_lower_quartile
# cell_WGA_lower_quartile
# cell_aTubulin_lower_quartile
# cell_Vimentin_lower_quartile
# cell_gH2AX_lower_quartile
# cell_Phalloidin_lower_quartile
# cell_DAPI_median
# cell_Ki-67_median
# cell_COXIV_median
# cell_Caspase-3_median
# cell_WGA_median
# cell_aTubulin_median
# cell_Vimentin_median
# cell_gH2AX_median
# cell_Phalloidin_median
# cell_DAPI_mad
# cell_Ki-67_mad
# cell_COXIV_mad
# cell_Caspase-3_mad
# cell_WGA_mad
# cell_aTubulin_mad
# cell_Vimentin_mad
# cell_gH2AX_mad
# cell_Phalloidin_mad
# cell_DAPI_upper_quartile
# cell_Ki-67_upper_quartile
# cell_COXIV_upper_quartile
# cell_Caspase-3_upper_quartile
# cell_WGA_upper_quartile
# cell_aTubulin_upper_quartile
# cell_Vimentin_upper_quartile
# cell_gH2AX_upper_quartile
# cell_Phalloidin_upper_quartile
# cell_DAPI_center_mass_r
# cell_Ki-67_center_mass_r
# cell_COXIV_center_mass_r
# cell_Caspase-3_center_mass_r
# cell_WGA_center_mass_r
# cell_aTubulin_center_mass_r
# cell_Vimentin_center_mass_r
# cell_gH2AX_center_mass_r
# cell_Phalloidin_center_mass_r
# cell_DAPI_center_mass_c
# cell_Ki-67_center_mass_c
# cell_COXIV_center_mass_c
# cell_Caspase-3_center_mass_c
# cell_WGA_center_mass_c
# cell_aTubulin_center_mass_c
# cell_Vimentin_center_mass_c
# cell_gH2AX_center_mass_c
# cell_Phalloidin_center_mass_c
# cell_DAPI_max_location_r
# cell_Ki-67_max_location_r
# cell_COXIV_max_location_r
# cell_Caspase-3_max_location_r
# cell_WGA_max_location_r
# cell_aTubulin_max_location_r
# cell_Vimentin_max_location_r
# cell_gH2AX_max_location_r
# cell_Phalloidin_max_location_r
# cell_DAPI_max_location_c
# cell_Ki-67_max_location_c
# cell_COXIV_max_location_c
# cell_Caspase-3_max_location_c
# cell_WGA_max_location_c
# cell_aTubulin_max_location_c
# cell_Vimentin_max_location_c
# cell_gH2AX_max_location_c
# cell_Phalloidin_max_location_c
# cell_DAPI_frac_at_d_0
# cell_Ki-67_frac_at_d_0
# cell_COXIV_frac_at_d_0
# cell_Caspase-3_frac_at_d_0
# cell_WGA_frac_at_d_0
# cell_aTubulin_frac_at_d_0
# cell_Vimentin_frac_at_d_0
# cell_gH2AX_frac_at_d_0
# cell_Phalloidin_frac_at_d_0
# cell_DAPI_frac_at_d_1
# cell_Ki-67_frac_at_d_1
# cell_COXIV_frac_at_d_1
# cell_Caspase-3_frac_at_d_1
# cell_WGA_frac_at_d_1
# cell_aTubulin_frac_at_d_1
# cell_Vimentin_frac_at_d_1
# cell_gH2AX_frac_at_d_1
# cell_Phalloidin_frac_at_d_1
# cell_DAPI_frac_at_d_2
# cell_Ki-67_frac_at_d_2
# cell_COXIV_frac_at_d_2
# cell_Caspase-3_frac_at_d_2
# cell_WGA_frac_at_d_2
# cell_aTubulin_frac_at_d_2
# cell_Vimentin_frac_at_d_2
# cell_gH2AX_frac_at_d_2
# cell_Phalloidin_frac_at_d_2
# cell_DAPI_frac_at_d_3
# cell_Ki-67_frac_at_d_3
# cell_COXIV_frac_at_d_3
# cell_Caspase-3_frac_at_d_3
# cell_WGA_frac_at_d_3
# cell_aTubulin_frac_at_d_3
# cell_Vimentin_frac_at_d_3
# cell_gH2AX_frac_at_d_3
# cell_Phalloidin_frac_at_d_3
# cell_DAPI_mean_frac_0
# cell_Ki-67_mean_frac_0
# cell_COXIV_mean_frac_0
# cell_Caspase-3_mean_frac_0
# cell_WGA_mean_frac_0
# cell_aTubulin_mean_frac_0
# cell_Vimentin_mean_frac_0
# cell_gH2AX_mean_frac_0
# cell_Phalloidin_mean_frac_0
# cell_DAPI_mean_frac_1
# cell_Ki-67_mean_frac_1
# cell_COXIV_mean_frac_1
# cell_Caspase-3_mean_frac_1
# cell_WGA_mean_frac_1
# cell_aTubulin_mean_frac_1
# cell_Vimentin_mean_frac_1
# cell_gH2AX_mean_frac_1
# cell_Phalloidin_mean_frac_1
# cell_DAPI_mean_frac_2
# cell_Ki-67_mean_frac_2
# cell_COXIV_mean_frac_2
# cell_Caspase-3_mean_frac_2
# cell_WGA_mean_frac_2
# cell_aTubulin_mean_frac_2
# cell_Vimentin_mean_frac_2
# cell_gH2AX_mean_frac_2
# cell_Phalloidin_mean_frac_2
# cell_DAPI_mean_frac_3
# cell_Ki-67_mean_frac_3
# cell_COXIV_mean_frac_3
# cell_Caspase-3_mean_frac_3
# cell_WGA_mean_frac_3
# cell_aTubulin_mean_frac_3
# cell_Vimentin_mean_frac_3
# cell_gH2AX_mean_frac_3
# cell_Phalloidin_mean_frac_3
# cell_DAPI_radial_cv_0
# cell_Ki-67_radial_cv_0
# cell_COXIV_radial_cv_0
# cell_Caspase-3_radial_cv_0
# cell_WGA_radial_cv_0
# cell_aTubulin_radial_cv_0
# cell_Vimentin_radial_cv_0
# cell_gH2AX_radial_cv_0
# cell_Phalloidin_radial_cv_0
# cell_DAPI_radial_cv_1
# cell_Ki-67_radial_cv_1
# cell_COXIV_radial_cv_1
# cell_Caspase-3_radial_cv_1
# cell_WGA_radial_cv_1
# cell_aTubulin_radial_cv_1
# cell_Vimentin_radial_cv_1
# cell_gH2AX_radial_cv_1
# cell_Phalloidin_radial_cv_1
# cell_DAPI_radial_cv_2
# cell_Ki-67_radial_cv_2
# cell_COXIV_radial_cv_2
# cell_Caspase-3_radial_cv_2
# cell_WGA_radial_cv_2
# cell_aTubulin_radial_cv_2
# cell_Vimentin_radial_cv_2
# cell_gH2AX_radial_cv_2
# cell_Phalloidin_radial_cv_2
# cell_DAPI_radial_cv_3
# cell_Ki-67_radial_cv_3
# cell_COXIV_radial_cv_3
# cell_Caspase-3_radial_cv_3
# cell_WGA_radial_cv_3
# cell_aTubulin_radial_cv_3
# cell_Vimentin_radial_cv_3
# cell_gH2AX_radial_cv_3
# cell_Phalloidin_radial_cv_3
# cell_DAPI_weighted_hu_moments_0
# cell_Ki-67_weighted_hu_moments_0
# cell_COXIV_weighted_hu_moments_0
# cell_Caspase-3_weighted_hu_moments_0
# cell_WGA_weighted_hu_moments_0
# cell_aTubulin_weighted_hu_moments_0
# cell_Vimentin_weighted_hu_moments_0
# cell_gH2AX_weighted_hu_moments_0
# cell_Phalloidin_weighted_hu_moments_0
# cell_DAPI_weighted_hu_moments_1
# cell_Ki-67_weighted_hu_moments_1
# cell_COXIV_weighted_hu_moments_1
# cell_Caspase-3_weighted_hu_moments_1
# cell_WGA_weighted_hu_moments_1
# cell_aTubulin_weighted_hu_moments_1
# cell_Vimentin_weighted_hu_moments_1
# cell_gH2AX_weighted_hu_moments_1
# cell_Phalloidin_weighted_hu_moments_1
# cell_DAPI_weighted_hu_moments_2
# cell_Ki-67_weighted_hu_moments_2
# cell_COXIV_weighted_hu_moments_2
# cell_Caspase-3_weighted_hu_moments_2
# cell_WGA_weighted_hu_moments_2
# cell_aTubulin_weighted_hu_moments_2
# cell_Vimentin_weighted_hu_moments_2
# cell_gH2AX_weighted_hu_moments_2
# cell_Phalloidin_weighted_hu_moments_2
# cell_DAPI_weighted_hu_moments_3
# cell_Ki-67_weighted_hu_moments_3
# cell_COXIV_weighted_hu_moments_3
# cell_Caspase-3_weighted_hu_moments_3
# cell_WGA_weighted_hu_moments_3
# cell_aTubulin_weighted_hu_moments_3
# cell_Vimentin_weighted_hu_moments_3
# cell_gH2AX_weighted_hu_moments_3
# cell_Phalloidin_weighted_hu_moments_3
# cell_DAPI_weighted_hu_moments_4
# cell_Ki-67_weighted_hu_moments_4
# cell_COXIV_weighted_hu_moments_4
# cell_Caspase-3_weighted_hu_moments_4
# cell_WGA_weighted_hu_moments_4
# cell_aTubulin_weighted_hu_moments_4
# cell_Vimentin_weighted_hu_moments_4
# cell_gH2AX_weighted_hu_moments_4
# cell_Phalloidin_weighted_hu_moments_4
# cell_DAPI_weighted_hu_moments_5
# cell_Ki-67_weighted_hu_moments_5
# cell_COXIV_weighted_hu_moments_5
# cell_Caspase-3_weighted_hu_moments_5
# cell_WGA_weighted_hu_moments_5
# cell_aTubulin_weighted_hu_moments_5
# cell_Vimentin_weighted_hu_moments_5
# cell_gH2AX_weighted_hu_moments_5
# cell_Phalloidin_weighted_hu_moments_5
# cell_DAPI_weighted_hu_moments_6
# cell_Ki-67_weighted_hu_moments_6
# cell_COXIV_weighted_hu_moments_6
# cell_Caspase-3_weighted_hu_moments_6
# cell_WGA_weighted_hu_moments_6
# cell_aTubulin_weighted_hu_moments_6
# cell_Vimentin_weighted_hu_moments_6
# cell_gH2AX_weighted_hu_moments_6
# cell_Phalloidin_weighted_hu_moments_6
# cell_DAPI_pftas_0
# cell_Ki-67_pftas_0
# cell_COXIV_pftas_0
# cell_Caspase-3_pftas_0
# cell_WGA_pftas_0
# cell_aTubulin_pftas_0
# cell_Vimentin_pftas_0
# cell_gH2AX_pftas_0
# cell_Phalloidin_pftas_0
# cell_DAPI_pftas_1
# cell_Ki-67_pftas_1
# cell_COXIV_pftas_1
# cell_Caspase-3_pftas_1
# cell_WGA_pftas_1
# cell_aTubulin_pftas_1
# cell_Vimentin_pftas_1
# cell_gH2AX_pftas_1
# cell_Phalloidin_pftas_1
# cell_DAPI_pftas_2
# cell_Ki-67_pftas_2
# cell_COXIV_pftas_2
# cell_Caspase-3_pftas_2
# cell_WGA_pftas_2
# cell_aTubulin_pftas_2
# cell_Vimentin_pftas_2
# cell_gH2AX_pftas_2
# cell_Phalloidin_pftas_2
# cell_DAPI_pftas_3
# cell_Ki-67_pftas_3
# cell_COXIV_pftas_3
# cell_Caspase-3_pftas_3
# cell_WGA_pftas_3
# cell_aTubulin_pftas_3
# cell_Vimentin_pftas_3
# cell_gH2AX_pftas_3
# cell_Phalloidin_pftas_3
# cell_DAPI_pftas_4
# cell_Ki-67_pftas_4
# cell_COXIV_pftas_4
# cell_Caspase-3_pftas_4
# cell_WGA_pftas_4
# cell_aTubulin_pftas_4
# cell_Vimentin_pftas_4
# cell_gH2AX_pftas_4
# cell_Phalloidin_pftas_4
# cell_DAPI_pftas_5
# cell_Ki-67_pftas_5
# cell_COXIV_pftas_5
# cell_Caspase-3_pftas_5
# cell_WGA_pftas_5
# cell_aTubulin_pftas_5
# cell_Vimentin_pftas_5
# cell_gH2AX_pftas_5
# cell_Phalloidin_pftas_5
# cell_DAPI_pftas_6
# cell_Ki-67_pftas_6
# cell_COXIV_pftas_6
# cell_Caspase-3_pftas_6
# cell_WGA_pftas_6
# cell_aTubulin_pftas_6
# cell_Vimentin_pftas_6
# cell_gH2AX_pftas_6
# cell_Phalloidin_pftas_6
# cell_DAPI_pftas_7
# cell_Ki-67_pftas_7
# cell_COXIV_pftas_7
# cell_Caspase-3_pftas_7
# cell_WGA_pftas_7
# cell_aTubulin_pftas_7
# cell_Vimentin_pftas_7
# cell_gH2AX_pftas_7
# cell_Phalloidin_pftas_7
# cell_DAPI_pftas_8
# cell_Ki-67_pftas_8
# cell_COXIV_pftas_8
# cell_Caspase-3_pftas_8
# cell_WGA_pftas_8
# cell_aTubulin_pftas_8
# cell_Vimentin_pftas_8
# cell_gH2AX_pftas_8
# cell_Phalloidin_pftas_8
# cell_DAPI_pftas_9
# cell_Ki-67_pftas_9
# cell_COXIV_pftas_9
# cell_Caspase-3_pftas_9
# cell_WGA_pftas_9
# cell_aTubulin_pftas_9
# cell_Vimentin_pftas_9
# cell_gH2AX_pftas_9
# cell_Phalloidin_pftas_9
# cell_DAPI_pftas_10
# cell_Ki-67_pftas_10
# cell_COXIV_pftas_10
# cell_Caspase-3_pftas_10
# cell_WGA_pftas_10
# cell_aTubulin_pftas_10
# cell_Vimentin_pftas_10
# cell_gH2AX_pftas_10
# cell_Phalloidin_pftas_10
# cell_DAPI_pftas_11
# cell_Ki-67_pftas_11
# cell_COXIV_pftas_11
# cell_Caspase-3_pftas_11
# cell_WGA_pftas_11
# ...
# cytoplasm_Caspase-3_haralick_5_2
# cytoplasm_WGA_haralick_5_2
# cytoplasm_aTubulin_haralick_5_2
# cytoplasm_Vimentin_haralick_5_2
# cytoplasm_gH2AX_haralick_5_2
# cytoplasm_Phalloidin_haralick_5_2
# cytoplasm_DAPI_haralick_5_3
# cytoplasm_Ki-67_haralick_5_3
# cytoplasm_COXIV_haralick_5_3
# cytoplasm_Caspase-3_haralick_5_3
# cytoplasm_WGA_haralick_5_3
# cytoplasm_aTubulin_haralick_5_3
# cytoplasm_Vimentin_haralick_5_3
# cytoplasm_gH2AX_haralick_5_3
# cytoplasm_Phalloidin_haralick_5_3
# cytoplasm_DAPI_haralick_5_4
# cytoplasm_Ki-67_haralick_5_4
# cytoplasm_COXIV_haralick_5_4
# cytoplasm_Caspase-3_haralick_5_4
# cytoplasm_zernike_4_2
# cytoplasm_zernike_4_4
# cytoplasm_zernike_5_1
# cytoplasm_zernike_5_3
# cytoplasm_zernike_5_5
# cytoplasm_zernike_6_0
# cytoplasm_zernike_6_2
# cytoplasm_zernike_6_4
# cytoplasm_zernike_6_6
# cytoplasm_zernike_7_1
# cytoplasm_zernike_7_3
# cytoplasm_zernike_7_5
# cytoplasm_zernike_7_7
# cytoplasm_zernike_8_0
# cytoplasm_zernike_8_2
# cytoplasm_zernike_8_4
# cytoplasm_zernike_8_6
# cytoplasm_zernike_8_8
# cytoplasm_zernike_9_1
# cytoplasm_zernike_9_3
# cytoplasm_zernike_9_5
# cytoplasm_zernike_9_7
# cytoplasm_zernike_9_9
# cytoplasm_number_neighbors_1
# cytoplasm_percent_touching_1
# cytoplasm_first_neighbor_distance
# cytoplasm_second_neighbor_distance
# cytoplasm_angle_between_neighbors

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Cell Data Metadata
#
# - `METADATA_COLS_FP`: Path to TSV to store metadata cols.
# - `METADATA_COLS`: Columns in cell data with metadata (use output above).

# %%
METADATA_COLS_FP = "config/cell_data_metadata_cols.tsv"
METADATA_COLS = [
    "plate",
    "well",
    "tile",
    "cell_0",
    "i_0",
    "j_0",
    "site",
    "cell_1",
    "i_1",
    "j_1",
    "distance",
    "fov_distance_0",
    "fov_distance_1",
    "cell_barcode_0",
    "gene_symbol_0",
    "no_recomb_0",
    "cell_barcode_1",
    "gene_symbol_1",
    "no_recomb_1",
    "mapped_single_gene",
    "channels_min",
    "nucleus_i",
    "nucleus_j",
    "nucleus_bounds_0",
    "nucleus_bounds_1",
    "nucleus_bounds_2",
    "nucleus_bounds_3",
    "cell_i",
    "cell_j",
    "cell_bounds_0",
    "cell_bounds_1",
    "cell_bounds_2",
    "cell_bounds_3",
    "cytoplasm_i",
    "cytoplasm_j",
    "cytoplasm_bounds_0",
    "cytoplasm_bounds_1",
    "cytoplasm_bounds_2",
    "cytoplasm_bounds_3",
]

# %%
pd.Series(METADATA_COLS).to_csv(METADATA_COLS_FP, index=False, header=False, sep="\t")

metadata, features = split_cell_data(cell_data, METADATA_COLS)
print(metadata.shape, features.shape)
# Out:
# (50000, 39) (50000, 4122)

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Split cells into classes
#
# - `CLASSIFIER_PATH`: Path to pickled Python object that can take a cell data dataframe and output cell classes
#
# ### Evaluate splitting
#
# - `COLLAPSE_COLS`: Cell data columns to collapse on when creating a summary of cell counts. This will show the number of cells in each cell class for these particular columns. Ex: `["sgRNA_0", "gene_symbol_0"]`.
# - `MONTAGE_CHANNEL`: Channel to use for montage generation. Usually `DAPI`.
#
# **Notes**:
# - We generate cell classes for each of the classes listed in the classifier and an "all" class. So for a classifier that splits by mitotic or interphase the final classes will be `["mitotic", "interphase", "all"]`.
# - You must import necessary packages for the classifier in this notebook and add them to `scripts/aggregate/split_datasets.py` as well. Ex `import numpy as np` if the classifier requires `numpy`.

# %%
CLASSIFIER_PATH = "config/binary_xgb_none_model.dill"
MONTAGE_CHANNEL = "DAPI"
COLLAPSE_COLS = ["cell_barcode_0", "gene_symbol_0"]

# %%
import numpy as np

classifier = CellClassifier.load(CLASSIFIER_PATH)
classified_metadata, classified_features = classifier.classify_cells(metadata, features)

# Create config var for cell classes
CELL_CLASSES = list(classified_metadata["class"].unique())

# Show cell class counts and distribution
print("Cell class counts:")
print(classified_metadata["class"].value_counts())

print("\nCell class confidences:")
classified_metadata["confidence"].hist()
plt.show()
# Out:
# /lab/barcheese01/mdiberna/miniconda3/envs/brieflow_etna/lib/python3.11/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /lab/barcheese01/mdiberna/miniconda3/envs/brieflow_etna/lib/python3.11/site-packages/sklearn/base.py:440: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Removing 3 rows with NaN values in features
# Cell class counts:
# class
# Interphase    47384
# Mitotic        2613
# Name: count, dtype: int64
#
# Cell class confidences:

# %%
cell_classes = list(classified_metadata["class"].unique()) + ["all"]

classified_metadata_copy = classified_metadata.copy(deep=True)
classified_metadata_copy = add_filenames(classified_metadata_copy, ROOT_FP)

# Create a dictionary of DataFrames for each cell class
cell_class_dfs = {
    cell_class: classified_metadata_copy[classified_metadata_copy["class"] == cell_class]
    for cell_class in CELL_CLASSES
}

# Define sorting directions and titles
title_templates = {
    True: "Lowest Confidence {cell_class} Cells - {channel}",
    False: "Highest Confidence {cell_class} Cells - {channel}",
}

# Generate montages dynamically
montages, titles = [], []
for cell_class, cell_df in cell_class_dfs.items():
    for ascending in [True, False]:
        montage = create_cell_montage(
            cell_data=cell_df,
            channels=config["phenotype"]["channel_names"],
            selection_params={
                "method": "sorted",
                "sort_by": "confidence",
                "ascending": ascending,
            },
        )[MONTAGE_CHANNEL]
        montages.append(montage)
        titles.append(
            title_templates[ascending].format(
                cell_class=cell_class, channel=MONTAGE_CHANNEL
            )
        )

# Determine figure size dynamically
num_rows = len(CELL_CLASSES)
fig, axes = plt.subplots(num_rows, 2, figsize=(10, 3 * num_rows))

# Display montages
for ax, title, montage in zip(axes.flat, titles, montages):
    ax.imshow(montage, cmap="gray")
    ax.set_title(title, fontsize=14)
    ax.axis("off")

print("Montages of cell classes:")
plt.tight_layout()
plt.show()

print("Split cell data summary:")
summary_df = summarize_cell_data(classified_metadata, CELL_CLASSES, COLLAPSE_COLS)
display(summary_df)
# Out:
# Montages of cell classes:
# Split cell data summary:
#                        Stage  Count  Percent
# 0                   Raw Data  49997   100.00
# 1           Interphase cells  47384    94.77
# 2  Interphase cell_barcode_0  10357    20.72
# 3   Interphase gene_symbol_0   1319     2.64
# 4              Mitotic cells   2613     5.23
# 5     Mitotic cell_barcode_0   1579     3.16
# 6      Mitotic gene_symbol_0    874     1.75

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Aggregate by channel combos
#
# - `CHANNEL_COMBOS`: Combinations of channels to aggregate by. This is a list of lists with channel names, ex `[["DAPI", "CENPA"], ["DAPI", "WGA"]]`.
# - `AGGREGATE_COMBO_FP`: Location of aggregate combinations dataframe.
# - `TEST_CELL_CLASS`: Cell class to configure aggregate params with. Can be any of the cell classes or `all`.
# - `TEST_CHANNEL_COMBO`: Channel combo to configure aggregate params with; must be one of the channel combos. Ex `["DAPI", "CENPA"]`.

# %%
CHANNEL_COMBOS = [["DAPI", "Ki-67", "COXIV", "Caspase-3", "WGA", "aTubulin", "Vimentin", "gH2AX", "Phalloidin"], ["DAPI", "aTubulin", "gH2AX", "Phalloidin"]]
AGGREGATE_COMBO_FP = "config/aggregate_combo.tsv"

TEST_CELL_CLASS = "all"
TEST_CHANNEL_COMBO = ["DAPI", "Ki-67", "COXIV", "Caspase-3", "WGA", "aTubulin", "Vimentin", "gH2AX", "Phalloidin"]

# %%
# determine cell classes and channel combos
channel_combos = ["_".join(combo) for combo in CHANNEL_COMBOS]

# Load merge wildcard combos
MERGE_COMBO_FP = Path(config["merge"]["merge_combo_fp"])
merge_wildcard_combos = pd.read_csv(MERGE_COMBO_FP, sep="\t")

# Generate aggregate wildcard combos
aggregate_wildcard_combos = pd.DataFrame(
    product(
        merge_wildcard_combos.itertuples(index=False, name=None),
        cell_classes,
        channel_combos,
    ),
    columns=["plate_well", "cell_class", "channel_combo"],
)
aggregate_wildcard_combos[["plate", "well"]] = pd.DataFrame(aggregate_wildcard_combos["plate_well"].tolist(), index=aggregate_wildcard_combos.index)
aggregate_wildcard_combos = aggregate_wildcard_combos.drop(columns="plate_well")

# Save aggregate wildcard combos
aggregate_wildcard_combos.to_csv(AGGREGATE_COMBO_FP, sep="\t", index=False)

print("Aggregate wildcard combos:")
aggregate_wildcard_combos
# Out:
# Aggregate wildcard combos:
#     cell_class                                      channel_combo  plate well
# 0   Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B2
# 1   Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      1   B2
# 2      Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B2
# 3      Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      1   B2
# 4          all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B2
# 5          all                     DAPI_aTubulin_gH2AX_Phalloidin      1   B2
# 6   Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A1
# 7   Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      1   A1
# 8      Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A1
# 9      Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      1   A1
# 10         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A1
# 11         all                     DAPI_aTubulin_gH2AX_Phalloidin      1   A1
# 12  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A3
# 13  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      1   A3
# 14     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A3
# 15     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      1   A3
# 16         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A3
# 17         all                     DAPI_aTubulin_gH2AX_Phalloidin      1   A3
# 18  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   B1
# 19  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      2   B1
# 20     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   B1
# 21     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      2   B1
# 22         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   B1
# 23         all                     DAPI_aTubulin_gH2AX_Phalloidin      2   B1
# 24  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   B3
# 25  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      2   B3
# 26     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   B3
# 27     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      2   B3
# 28         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   B3
# 29         all                     DAPI_aTubulin_gH2AX_Phalloidin      2   B3
# 30  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   A1
# 31  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      2   A1
# 32     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   A1
# 33     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      2   A1
# 34         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      2   A1
# 35         all                     DAPI_aTubulin_gH2AX_Phalloidin      2   A1
# 36  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A2
# 37  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      1   A2
# 38     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A2
# 39     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      1   A2
# 40         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   A2
# 41         all                     DAPI_aTubulin_gH2AX_Phalloidin      1   A2
# 42  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B1
# 43  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      1   B1
# 44     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B1
# 45     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      1   B1
# 46         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B1
# 47         all                     DAPI_aTubulin_gH2AX_Phalloidin      1   B1
# 48  Interphase  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B3
# 49  Interphase                     DAPI_aTubulin_gH2AX_Phalloidin      1   B3
# 50     Mitotic  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B3
# 51     Mitotic                     DAPI_aTubulin_gH2AX_Phalloidin      1   B3
# 52         all  DAPI_Ki-67_COXIV_Caspase-3_WGA_aTubulin_Viment...      1   B3
# 53         all                     DAPI_aTubulin_gH2AX_Phalloidin      1   B3

# %%
# subset cell class
if TEST_CELL_CLASS != "all":
    cell_class_mask = classified_metadata["class"] == TEST_CELL_CLASS
    class_metadata = classified_metadata[cell_class_mask]
    class_features = classified_features[cell_class_mask]
else:
    class_metadata = classified_metadata
    class_features = classified_features

# subset features
all_channels = config["phenotype"]["channel_names"]
class_features = channel_combo_subset(class_features, TEST_CHANNEL_COMBO, all_channels)

# copy metadata and features for later eval
dataset_metadata = class_metadata.copy()
dataset_features = class_features.copy()

# preview metadata and features
display(class_metadata)
display(class_features)
# Out:
#        plate well  tile  cell_0          i_0          j_0  site  cell_1  \
# 0          1   A1   514     841  1479.657100  1480.528701   140    2684
# 1          1   A1   129     410  1480.853636  1479.342273    36    2128
# 2          1   A1  1300     524  1478.354236  1478.312542   352    1033
# 3          1   A1  1249     432  1482.248657  1479.001466   325    2576
# 4          1   A1  1086     590  1483.420965  1477.997504   303    1467
# ...      ...  ...   ...     ...          ...          ...   ...     ...
# 49995      1   A2   441     484  1623.648581  1686.254591   136    1098
# 49996      1   A2   512     580  1597.578726  1702.158153   139    3593
# 49997      1   A2    29     304  1228.653559  1477.918865     9    1888
# 49998      1   A2   428     455  1244.867795  1568.860391   102    2514
# 49999      1   A2   621     313  1228.765971  1471.665402   171     637
#
#                i_1          j_1  ...  cell_bounds_2  cell_bounds_3  \
# 0       482.533333   439.355556  ...           1519           1524
# 1      1032.202381   482.273810  ...           1570           1517
# 2       362.226804   361.036082  ...           1535           1535
# 3       990.076023   998.456140  ...           1535           1534
# 4       456.075630  1016.319328  ...           1529           1530
# ...            ...          ...  ...            ...            ...
# 49995   488.268041   499.556701  ...           1667           1736
# 49996  1136.683761   501.683761  ...           1643           1755
# 49997   969.857955   496.948864  ...           1291           1535
# 49998  1034.255556   474.433333  ...           1295           1605
# 49999   330.919463  1062.765101  ...           1276           1526
#
#        cytoplasm_i  cytoplasm_j cytoplasm_bounds_0 cytoplasm_bounds_1  \
# 0      1479.430737  1495.779789               1435               1449
# 1      1485.434249  1471.806960               1424               1433
# 2      1499.396767  1485.672055               1439               1427
# 3      1485.205971  1468.633663               1428               1397
# 4      1492.324813  1484.869041               1458               1442
# ...            ...          ...                ...                ...
# 49995  1619.232332  1688.735392               1578               1643
# 49996  1601.690904  1714.721814               1557               1664
# 49997  1236.581585  1470.840631               1180               1419
# 49998  1235.537263  1558.339770               1206               1517
# 49999  1226.682899  1463.355637               1177               1422
#
#       cytoplasm_bounds_2 cytoplasm_bounds_3       class confidence
# 0                   1519               1524  Interphase   0.999843
# 1                   1570               1517  Interphase   0.999735
# 2                   1535               1535  Interphase   0.998644
# 3                   1535               1534  Interphase   0.999910
# 4                   1529               1530     Mitotic   0.999941
# ...                  ...                ...         ...        ...
# 49995               1667               1736  Interphase   0.999874
# 49996               1643               1755  Interphase   0.999906
# 49997               1291               1535  Interphase   0.979077
# 49998               1295               1605     Mitotic   0.901827
# 49999               1276               1526  Interphase   0.999872
#
# [49997 rows x 41 columns]
#        nucleus_DAPI_int  nucleus_Ki-67_int  nucleus_COXIV_int  \
# 0              13473422            2442160            2395658
# 1              20443423           14470365            2019354
# 2              27596253           11878060            3575554
# 3              19667493            9559414            2721136
# 4              23182412           34744971            4435125
# ...                 ...                ...                ...
# 49995          11372967            8661956            2950054
# 49996          11871354            6445360            1485921
# 49997          26037813           23085778            2444785
# 49998          21058285            6616981            2769889
# 49999          11794329            6402514            1897328
#
#        nucleus_Caspase-3_int  nucleus_WGA_int  nucleus_aTubulin_int  \
# 0                    2041128          9685770               2206564
# 1                    3030007         12021365               3543333
# 2                    4574096         21326697               5402880
# 3                    2934051         10850031               3105887
# 4                    3398764          9886431               6414303
# ...                      ...              ...                   ...
# 49995                2020040          9256187               2110110
# 49996                2062712          9175888               1936969
# 49997                3282770         11605101               3951599
# 49998                4738469         18334122               2864400
# 49999                2228854          9407307               2137400
#
#        nucleus_Vimentin_int  nucleus_gH2AX_int  nucleus_Phalloidin_int  \
# 0                   4835758            1969004                 4278515
# 1                   8250542            3204963                 4658511
# 2                   9734729            4272295                 7221774
# 3                   5425850            2939495                 5359409
# 4                   4991808            2066662                 3816818
# ...                     ...                ...                     ...
# 49995               4653219            1724894                 2584444
# 49996               3751019            1960670                 3024218
# 49997               5394953            2902033                 5134174
# 49998               5998809            2737876                 5001497
# 49999               5195844            2186520                 3246827
#
#        nucleus_DAPI_mean  ...  cytoplasm_zernike_9_1  cytoplasm_zernike_9_3  \
# 0           10176.300604  ...               0.096474               0.075336
# 1            9292.465000  ...               0.032118               0.051637
# 2            9204.887592  ...               0.047223               0.058451
# 3            9607.959453  ...               0.027419               0.049565
# 4           19286.532446  ...               0.065412               0.026204
# ...                  ...  ...                    ...                    ...
# 49995        9493.294658  ...               0.017427               0.080226
# 49996        8307.455563  ...               0.096492               0.016776
# 49997       12960.583873  ...               0.030530               0.049919
# 49998       11136.057641  ...               0.075163               0.026355
# 49999        7460.043643  ...               0.069208               0.045427
#
#        cytoplasm_zernike_9_5  cytoplasm_zernike_9_7  cytoplasm_zernike_9_9  \
# 0                   0.041893               0.063991               0.023977
# 1                   0.080861               0.062261               0.019221
# 2                   0.025184               0.015263               0.011378
# 3                   0.002138               0.050710               0.030450
# 4                   0.076101               0.016644               0.021584
# ...                      ...                    ...                    ...
# 49995               0.024950               0.041787               0.009289
# 49996               0.029052               0.006651               0.031137
# 49997               0.021309               0.009734               0.021220
# 49998               0.133785               0.106438               0.080470
# 49999               0.074232               0.025283               0.006416
#
#        cytoplasm_number_neighbors_1  cytoplasm_percent_touching_1  \
# 0                                 3                      0.400000
# 1                                 6                      0.580460
# 2                                 5                      0.533742
# 3                                 5                      0.601732
# 4                                 4                      0.597077
# ...                             ...                           ...
# 49995                             4                      0.553640
# 49996                             6                      0.667939
# 49997                             5                      0.468798
# 49998                             5                      0.524150
# 49999                             4                      0.632653
#
#        cytoplasm_first_neighbor_distance  cytoplasm_second_neighbor_distance  \
# 0                              52.315316                           61.488805
# 1                              67.654669                           85.746446
# 2                              69.517492                           79.197079
# 3                              65.975278                           66.433083
# 4                              69.132273                           73.365904
# ...                                  ...                                 ...
# 49995                          70.180811                           70.523472
# 49996                          80.207366                           81.476249
# 49997                          83.887045                           90.403964
# 49998                          59.698493                           61.090044
# 49999                          74.117513                           76.267903
#
#        cytoplasm_angle_between_neighbors
# 0                             123.993893
# 1                             154.688886
# 2                             136.690890
# 3                             176.821726
# 4                             139.537211
# ...                                  ...
# 49995                          65.284275
# 49996                         154.646724
# 49997                         167.108292
# 49998                          76.440311
# 49999                         138.685250
#
# [49997 rows x 4122 columns]

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Perturbation filtering
#
# - `FILTER_QUERIES`: Queries to use for custom filtering; ex: `["mapped_single_gene == True", "cell_quality_score > 0.8"]`. Can be left as `None` for no filtering.
# - `PERTURBATION_NAME_COL`: Name of column used to identify perturbations. This is the column that aggregation takes place on. Ex "gene_symbol_0".

# %%
FILTER_QUERIES = ["mapped_single_gene == True", "no_recomb_0 == True"]
PERTURBATION_NAME_COL = "gene_symbol_0"

# %%
# Filter to cells that have a value for gene_symbol_0 (not null/NaN)
cells_with_gene_symbol = class_metadata[class_metadata['gene_symbol_0'].notna()]

# Calculate the percentage where mapped_single_gene == True
percentage = (cells_with_gene_symbol['mapped_single_gene'] == True).mean() * 100

print(f"Percentage of cells with gene_symbol_0 that have mapped_single_gene == True: {percentage:.2f}%")
# Out:
# Percentage of cells with gene_symbol_0 that have mapped_single_gene == True: 97.76%

# %%
print(cells_with_gene_symbol['no_recomb_0'].value_counts(dropna=False))
# Out:
# no_recomb_0
# True     26666
# False     6891
# None      3384
# Name: count, dtype: int64

# %%
qf_metadata, qf_features = query_filter(class_metadata, class_features, FILTER_QUERIES)

pf_metadata, pf_features = perturbation_filter(
    qf_metadata, qf_features, PERTURBATION_NAME_COL
)
print(f"Unique populations: {metadata[PERTURBATION_NAME_COL].nunique()}")

summary_df, fig = nas_summary(pf_features)
print(summary_df[summary_df["percent_na"] > 0.1])
plt.show()
# Out:
# Query 'mapped_single_gene == True' filtered out 13882 cells
# Query 'no_recomb_0 == True' filtered out 9986 cells
# Found 26129 cells with assigned perturbations
# Unique populations: 1320
#                               column  percent_na
# 0         cytoplasm_DAPI_mean_frac_0    0.710666
# 1        cytoplasm_Ki-67_mean_frac_0    0.710666
# 2        cytoplasm_COXIV_mean_frac_0    0.710666
# 3    cytoplasm_Caspase-3_mean_frac_0    0.710666
# 4          cytoplasm_WGA_mean_frac_0    0.710666
# 5     cytoplasm_aTubulin_mean_frac_0    0.710666
# 6     cytoplasm_Vimentin_mean_frac_0    0.710666
# 7        cytoplasm_gH2AX_mean_frac_0    0.710666
# 8   cytoplasm_Phalloidin_mean_frac_0    0.710666
# 18        cytoplasm_DAPI_radial_cv_0    0.710666
# 19       cytoplasm_Ki-67_radial_cv_0    0.710666
# 20       cytoplasm_COXIV_radial_cv_0    0.710666
# 21   cytoplasm_Caspase-3_radial_cv_0    0.710666
# 22         cytoplasm_WGA_radial_cv_0    0.710666
# 23    cytoplasm_aTubulin_radial_cv_0    0.710666
# 24    cytoplasm_Vimentin_radial_cv_0    0.710666
# 25       cytoplasm_gH2AX_radial_cv_0    0.710666
# 26  cytoplasm_Phalloidin_radial_cv_0    0.710666

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Missing value filtering
#
# - `DROP_COLS_THRESHOLD`: Threshold of NA values above which an entire column is dropped. Usually `0.1`
# - `DROP_ROWS_THRESHOLD`: Threshold of NA values above which an entire row is dropped. Usually `0.01`
# - `IMPUTE`: Whether or not to impute remaining missing values. Usually `True`
#
# **Note**: All NAs must be dropped or imputed to perform feature alignment.

# %%
DROP_COLS_THRESHOLD = 0.1
DROP_ROWS_THRESHOLD = 0.01
IMPUTE = True

# %%
# Filter by missing values
mvf_metadata, mvf_features = missing_values_filter(
    pf_metadata,
    pf_features,
    drop_cols_threshold=DROP_COLS_THRESHOLD,
    drop_rows_threshold=DROP_ROWS_THRESHOLD,
    impute=True,
)

mvf_metadata.shape, mvf_features.shape
# Out:
# Dropping 18 columns with ≥10.0% missing values
# Dropped 0 rows with ≥1.0% missing values
# Imputing 18 columns with remaining missing values using batched KNN
# Imputing for batch 1 with 613 NA rows
# ((26129, 41), (26129, 4104))

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Intensity filtering
#
# - `CONTAMINATION`: Expected proportion of outliers in dataset. Usually `0.01`

# %%
CONTAMINATION = 0.01

# %%
# Filter by intensity outliers
if_metadata, if_features = intensity_filter(
    mvf_metadata,
    mvf_features,
    config["phenotype"]["channel_names"],
    CONTAMINATION,
)

if_metadata.shape, if_features.shape
# Out:
# ((25867, 41), (25867, 4104))

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Prepare alignment data
#
# - `BATCH_COLS`: Which columns of metadata have batch-specific information. Usually `["plate", "well"]`.
# - `CONTROL_KEY`: Name of perturbation in `PERTURBATION_NAME_COL` that indicates a control cell.
# - `PERTURBATION_ID_COL`: Name of column that identifies unique perturbations. Only needed if you want your controls to have different perturbation names, ex `sgRNA_0`. Otherwise, can leave this as `None`.

# %%
BATCH_COLS = ["plate", "well"]
CONTROL_KEY = "nontargeting"
PERTURBATION_ID_COL = "cell_barcode_0"

# %%
pad_metadata, pad_features = prepare_alignment_data(
    if_metadata, if_features, BATCH_COLS, PERTURBATION_NAME_COL, CONTROL_KEY, PERTURBATION_ID_COL
)

n_components, fig = pca_variance_plot(
    pad_features, variance_threshold=0.99
)
plt.show()

# %% [markdown]
# ## <font color='red'>SET PARAMETERS</font>
#
# ### Align and aggregate
#
# - `VARIANCE_OR_NCOMP`: Variance or number of components to keep after PCA.
# - `NUM_ALIGN_BATCHES`: Number of batches to use when aligning, usually `1`. Increase this if you are running out of memory while aligning. We were able to barely fit 8 plates with 6 wells each in 1 TB of memory with `NUM_ALIGN_BATCHES=1`.
# - `AGG_METHOD`: Method used to aggregate features. Can be `mean` or `median`. Usually `median`.
#
# While we use a simplified aggregate method in the notebook, the way this works during a normal run is:
# 1) Take a subset of 1,000,000 cells, or the entire dataset, whichever is smaller and compute a PCA transform with `VARIANCE_OR_NCOMP`.
# 2) Subset the entire dataset `NUM_BATCHES` number of times and align cells in this batch.
# 3) Aggregate across all aligned cell data.

# %%
VARIANCE_OR_NCOMP = 0.99
NUM_ALIGN_BATCHES = 1
AGG_METHOD = "median"

# %%
pca_embeddings = embed_by_pca(
    pad_features, pad_metadata, variance_or_ncomp=VARIANCE_OR_NCOMP, batch_col="batch_values"
)

tvn_normalized = tvn_on_controls(
    pca_embeddings, pad_metadata, PERTURBATION_NAME_COL, CONTROL_KEY, "batch_values"
)

aggregated_embeddings, aggregated_metadata = aggregate(
    tvn_normalized, pad_metadata, PERTURBATION_NAME_COL, AGG_METHOD
)

feature_columns = [f"PC_{i}" for i in range(tvn_normalized.shape[1])]

tvn_normalized_df = pd.DataFrame(
    tvn_normalized, index=pad_metadata.index, columns=feature_columns
)
aligned_cell_data = pd.concat([pad_metadata, tvn_normalized_df], axis=1)

aggregated_embeddings_df = pd.DataFrame(
    aggregated_embeddings, index=aggregated_metadata.index, columns=feature_columns
)
aggregated_cell_data = (
    pd.concat([aggregated_metadata, aggregated_embeddings_df], axis=1)
    .sort_values("cell_count", ascending=False)
    .reset_index(drop=True)
)
# Out:
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/align.py:244: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/align.py:244: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/align.py:174: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/align.py:179: ComplexWarning: Casting complex values to real discards the imaginary part
#   embeddings[batch_ind] = np.matmul(
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/align.py:174: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   batch_ind & (metadata[pert_col].str.startswith(control_key)).to_list()
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/align.py:179: ComplexWarning: Casting complex values to real discards the imaginary part
#   embeddings[batch_ind] = np.matmul(

# %%
original_feature_cols = [col for col in dataset_features.columns if ("cell_" in col and col.endswith("_mean"))]
pc_cols = [col for col in aggregated_cell_data.columns if col.startswith("PC_")]
aligned_feature_cols = random.sample(pc_cols, k=min(len(original_feature_cols), len(pc_cols)))

original_cell_data = pd.concat([dataset_metadata, dataset_features], axis=1)
original_cell_data

feature_distributions_fig = plot_feature_distributions(
    original_feature_cols,
    original_cell_data,
    aligned_feature_cols,
    aligned_cell_data,
)
plt.show()
# Out:
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/eval_aggregate.py:130: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_orig = df_orig.groupby(["Feature", "plate_well"], group_keys=False).apply(
# /lab/ops_analysis/cheeseman/etna-analysis/brieflow/workflow/lib/aggregate/eval_aggregate.py:136: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_aligned = df_aligned.groupby(["Feature", "plate_well"], group_keys=False).apply(

# %% [markdown]
# ## Add aggregate parameters to config file

# %%
# Add aggregate section
config["aggregate"] = {
    "metadata_cols_fp": METADATA_COLS_FP,
    "collapse_cols": COLLAPSE_COLS,
    "classifier_path": CLASSIFIER_PATH,
    "aggregate_combo_fp": AGGREGATE_COMBO_FP,
    "filter_queries": FILTER_QUERIES,
    "perturbation_name_col": PERTURBATION_NAME_COL,
    "drop_cols_threshold": DROP_COLS_THRESHOLD,
    "drop_rows_threshold": DROP_ROWS_THRESHOLD,
    "impute": IMPUTE,
    "contamination": CONTAMINATION,
    "batch_cols": BATCH_COLS,
    "control_key": CONTROL_KEY,
    "perturbation_id_col": PERTURBATION_ID_COL,
    "variance_or_ncomp": VARIANCE_OR_NCOMP,
    "num_align_batches": NUM_ALIGN_BATCHES,
    "agg_method": AGG_METHOD,
}

# Write the updated configuration
with open(CONFIG_FILE_PATH, "w") as config_file:
    # Write the introductory comments
    config_file.write(CONFIG_FILE_HEADER)

    # Dump the updated YAML structure, keeping markdown comments for sections
    yaml.dump(config, config_file, default_flow_style=False, sort_keys=False)
